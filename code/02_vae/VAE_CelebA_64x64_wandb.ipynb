# %% [markdown]
# # Variational Autoencoder applied to CelebA Dataset
#
# The VAE model was adapted from https://github.com/AntixK/PyTorch-VAE/.
#
# The model was trained on the CelebA dataset: http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html
#
# Images were resized to 64x64 pixels.
#
# Antonio Esteves @ UMinho, Mar 2024

# %% [markdown]
# ## Import necessary libraries

# %%
import os
from   pathlib  import Path
import pandas   as     pd
import torch
import torch.nn as     nn
from   torch.nn import functional as F
from   typing   import List, TypeVar, Tuple, Dict, Union #  Callable, Any, Optional, Sequence

Tensor = TypeVar('torch.tensor')

# %% [markdown]
# ## Import W&B and Login

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: ajesteves. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Read the configuration file

# %%
import yaml

BASE_FILE_NAME = "VAE_CelebA_64x64_04"
CONFIG_FILE    = 'config/vae_antixk_config.yaml'

with open(CONFIG_FILE, 'r') as file:
    try:
        config = yaml.safe_load(file)
    except yaml.YAMLError as exc:
        print(exc)

# %%
config
# Out:
# {'model_params': {'name': 'VAE', 'in_channels': 3, 'latent_dim': 128},
#  'data_params': {'data_path': '/home/datasets/celeba',
#   'train_batch_size': 64,
#   'val_batch_size': 64,
#   'test_batch_size': 144,
#   'patch_size': 64,
#   'num_workers': 4,
#   'pin_memory': True},
#  'exp_params': {'LR': 0.001,
#   'weight_decay': 0.0,
#   'scheduler_gamma': 0.95,
#   'kld_weight': 1.0,
#   'accelerator': 'gpu',
#   'epochs': 100,
#   'manual_seed': 1265},
#  'logging_params': {'save_dir': 'logs/', 'name': 'VAE'}}

# %% [markdown]
# ## Track metadata and hyperparameters with `wandb.init`
#
# Define the experiment: the hyperparameters, the dataset and model name. This information will be stored in a `config` dictionary.

# %%
config_wandb = dict(
    epochs        = config["exp_params"]["epochs"],
    batch_size    = config["data_params"]["train_batch_size"],
    learning_rate = config["exp_params"]["LR"],
    kld_weight    = config["exp_params"]["kld_weight"],
    optimizer     = "Adam",
    dataset       = "CelebA",
    image_size    = [
                    config["model_params"]["in_channels"],
                    config["data_params"]["patch_size"],
                    config["data_params"]["patch_size"]
                    ],
    latent_dim    = config["model_params"]["latent_dim"],
    architecture  = "VAE-cnn"
)

# %%
config_wandb
# Out:
# {'epochs': 100,
#  'batch_size': 64,
#  'learning_rate': 0.001,
#  'optimizer': 'Adam',
#  'dataset': 'CelebA',
#  'image_size': [3, 64, 64],
#  'latent_dim': 128,
#  'architecture': 'VAE-cnn'}

# %%
wandb.init(project='VAE_CelebA', entity='ajesteves', config=config_wandb)
# Out:
# wandb version 0.16.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/esteves/pCloudDrive/sabatica2023/codigo/VAE/wandb/run-20240327_035404-e1q5t1ci</code>
# Syncing run <strong><a href='https://wandb.ai/ajesteves/VAE_CelebA/runs/e1q5t1ci' target="_blank">mild-shadow-7</a></strong> to <a href='https://wandb.ai/ajesteves/VAE_CelebA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ajesteves/VAE_CelebA' target="_blank">https://wandb.ai/ajesteves/VAE_CelebA</a>
#  View run at <a href='https://wandb.ai/ajesteves/VAE_CelebA/runs/e1q5t1ci' target="_blank">https://wandb.ai/ajesteves/VAE_CelebA/runs/e1q5t1ci</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/ajesteves/VAE_CelebA/runs/e1q5t1ci?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## Prepare the data and explore it

# %%
print(torch.__version__)

# setup device agnostic code

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)

# Setup path to celebA dataset folder

data_path = Path(config["data_params"]["data_path"])

train_dir = data_path / "train"
val_dir   = data_path / "val"
test_dir  = data_path / "test"
# Out:
# 2.1.1+cu121
# cuda

# %%
# Get all training image paths
train_image_list = list(train_dir.glob("*.jpg")) 

print(f'Training set size: {len(train_image_list)}')

# Get all validation image paths
val_image_list = list(val_dir.glob("*.jpg")) 

print(f'Validation set size: {len(val_image_list)}')

# Get all test image paths
test_image_list = list(test_dir.glob("*.jpg"))

print(f'Test set size: {len(test_image_list)}')
# Out:
# Training set size: 162770
# Validation set size: 19867
# Test set size: 19962

# %%
# Visualizing random images

import random
from   PIL import Image

# set seed

random.seed(42)

# Pick a random image path

rand_image_path = random.choice(train_image_list)
print(f'Randomly selected image:\n\t{rand_image_path}')

# Open the image using pillow library

img = Image.open(rand_image_path)

# Show the image and print image metadata

print(f'Random image path:   {rand_image_path}')
print(f'Random image height: {img.height}')
print(f'Random image width:  {img.width}')

display(img)
# Out:
# Randomly selected image:
# 	/home/datasets/celeba/train/029185.jpg
# Random image path:   /home/datasets/celeba/train/029185.jpg
# Random image height: 218
# Random image width:  178
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>

# %%
# Visualize an image using matplotlib

import numpy as np
import matplotlib.pyplot as plt

# convert the image 'img' to a numpy array

img_array = np.asarray(img)

# plot the image with matplotlib

plt.figure(figsize=(10,7))
plt.imshow(img_array)
plt.title(f'Image shape: {img_array.shape} (height,width,channels)')
plt.axis(False)
# Out:
# (-0.5, 177.5, 217.5, -0.5)

# %% [markdown]
# ## Transforming the Data
#
# Before we can use our data with PyTorch:
# 1. Convert the images to tensors using `torchvision.transforms`
# ([documentation](https://pytorch.org/vision/0.16//transforms.html))
# 2. Create a `torch.utils.data.Dataset` with our tensors
# 3. Convert the `Dataset` into a `torch.utils.data.DataLoader`
#
# ### (i) Convert images to tensors

# %%
from torch.utils.data import DataLoader
from torchvision      import transforms, datasets

train_transforms = transforms.Compose(
    [
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(148),
    transforms.Resize(config["data_params"]["patch_size"]),
    transforms.ToTensor()
    ]
)

val_transforms = transforms.Compose(
    [
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(148),
    transforms.Resize(config["data_params"]["patch_size"]),
    transforms.ToTensor()
    ]
)

# %%
img_tensor = train_transforms(img)
print(img_tensor.shape)
print(img_tensor)
# Out:
# torch.Size([3, 64, 64])
# tensor([[[0.1294, 0.1569, 0.2314,  ..., 0.0980, 0.0980, 0.1020],
#          [0.1255, 0.1608, 0.2392,  ..., 0.1020, 0.1020, 0.1059],
#          [0.1373, 0.1490, 0.2353,  ..., 0.1020, 0.1020, 0.1059],
#          ...,
#          [0.1059, 0.0980, 0.0980,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1098, 0.1020, 0.1020,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1098, 0.1020, 0.0980,  ..., 0.0824, 0.0824, 0.0824]],
#
#         [[0.1529, 0.1765, 0.2510,  ..., 0.1216, 0.1216, 0.1255],
#          [0.1490, 0.1804, 0.2588,  ..., 0.1255, 0.1255, 0.1294],
#          [0.1569, 0.1725, 0.2510,  ..., 0.1255, 0.1255, 0.1294],
#          ...,
#          [0.1294, 0.1176, 0.1137,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1294, 0.1216, 0.1137,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1333, 0.1176, 0.1098,  ..., 0.0824, 0.0824, 0.0824]],
#
#         [[0.1333, 0.1608, 0.2314,  ..., 0.1216, 0.1216, 0.1255],
#          [0.1294, 0.1647, 0.2431,  ..., 0.1255, 0.1255, 0.1294],
#          [0.1412, 0.1569, 0.2353,  ..., 0.1255, 0.1255, 0.1294],
#          ...,
#          [0.1333, 0.1216, 0.1176,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1373, 0.1255, 0.1176,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1373, 0.1255, 0.1137,  ..., 0.0824, 0.0824, 0.0824]]])

# %%
# Visualize transformed images

def plot_transformed_images(
    image_paths,
    transform,
    n           = 3,
    seed        = None ):
  """
  The functions selects 'n' random images from 'image_paths', load and transform them,
  then it plots the original images vs the transformed representation.
  """
  # set the random seed if it is not None
  if seed:
    random.seed(seed)

  # randomly select 'n' image paths
  rand_image_paths = random.sample(image_paths,k=n)

  # iterate throuth the 'n' selected paths
  for image_path in rand_image_paths:

    with Image.open(image_path) as f:

      # original image
      fig,ax = plt.subplots(nrows=1,ncols=2)
      ax[0].imshow(f)
      ax[0].set_title(f'Original\nSize: {f.size}')
      ax[0].axis(False)

      # transform the original image and plot the transformed representation
      transformed_image = transform(f).permute(1, 2, 0) # we need to convert C,H,W (pytorch) to H,W,C (plt)
      ax[1].imshow(transformed_image)
      ax[1].set_title(f'Transformed\nShape: {transformed_image.shape}')
      ax[1].axis(False)

      fig.suptitle(f'Class: {image_path.parent.stem}',fontsize=16)

# %%
plot_transformed_images(
    image_paths = train_image_list,
    transform   = train_transforms,
    n           = 3
)

# %% [markdown]
# ### (ii) Create a custom Dataset from the images in a folder using `torch.utils.data.Dataset`

# %%
from natsort          import natsorted
from torch.utils.data import Dataset

class CustomDataSet(Dataset):

    def __init__(self, root_dir, transform):
        self.root_dir     = root_dir
        self.transform    = transform
        self.all_images   = os.listdir(root_dir)
        self.total_images = natsorted(self.all_images)

    def __len__(self):
        return len(self.total_images)

    def __getitem__(self, idx):
        img_loc = os.path.join(self.root_dir, self.total_images[idx])
        image   = Image.open(img_loc).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image

# %%
# Create training and validation datasets

train_data = CustomDataSet(
    train_dir,
    transform = train_transforms
)

val_data = CustomDataSet(
    val_dir,
    transform = val_transforms
)

test_data = CustomDataSet(
    test_dir,
    transform = val_transforms
)

print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 162770
# 19867
# 19962

# %%
# Visualize some samples from the created training set

# Indexing the 'train_data' Dataset to get a single (image, label) sample

img  = train_data[0]

print(f'Image tensor:\n{img}')
print(f'Image shape: {img.shape}')
print(f'Image data type: {img.dtype}')
# Out:
# Image tensor:
# tensor([[[0.6353, 0.4471, 0.4118,  ..., 0.9882, 0.9843, 0.9843],
#          [0.6471, 0.5020, 0.3882,  ..., 0.9882, 0.9843, 0.9882],
#          [0.6706, 0.4980, 0.4980,  ..., 0.9882, 0.9882, 0.9882],
#          ...,
#          [0.5373, 0.2549, 0.2510,  ..., 0.5765, 0.5490, 0.5333],
#          [0.5490, 0.2275, 0.2471,  ..., 0.6275, 0.5765, 0.5294],
#          [0.5137, 0.2627, 0.2902,  ..., 0.6078, 0.5804, 0.5137]],
#
#         [[0.4824, 0.2549, 0.2196,  ..., 0.9373, 0.9333, 0.9255],
#          [0.5059, 0.3098, 0.1922,  ..., 0.9373, 0.9333, 0.9373],
#          [0.5216, 0.3137, 0.3098,  ..., 0.9373, 0.9373, 0.9333],
#          ...,
#          [0.3608, 0.1216, 0.0863,  ..., 0.3490, 0.3137, 0.3059],
#          [0.3686, 0.0980, 0.0706,  ..., 0.3843, 0.3373, 0.3020],
#          [0.3373, 0.1216, 0.0980,  ..., 0.3569, 0.3412, 0.2863]],
#
#         [[0.3255, 0.1373, 0.1176,  ..., 0.8039, 0.8000, 0.7961],
#          [0.3137, 0.1882, 0.1020,  ..., 0.8078, 0.8039, 0.8078],
#          [0.3373, 0.1922, 0.2196,  ..., 0.8118, 0.8118, 0.8078],
#          ...,
#          [0.2941, 0.0980, 0.0549,  ..., 0.2471, 0.2118, 0.1961],
#          [0.3020, 0.0706, 0.0353,  ..., 0.2588, 0.2275, 0.1922],
#          [0.2588, 0.0863, 0.0549,  ..., 0.2039, 0.2196, 0.1686]]])
# Image shape: torch.Size([3, 64, 64])
# Image data type: torch.float32

# %%
# rearrange the order of dimensions on image tensor for using matplot lib
img_permuted = img.permute(1, 2, 0) # C,H,W --> H,W,C

# print shapes
print(f'Original image shape (pytorch tensor):   {img.shape}')
print(f'Permute image shape (matplotlib format): {img_permuted.shape}')

# plot the image

plt.figure(figsize=(10,7))
plt.imshow(img_permuted)
plt.axis(False)
plt.title(f'An image from training set')
# Out:
# Original image shape (pytorch tensor):   torch.Size([3, 64, 64])
# Permute image shape (matplotlib format): torch.Size([64, 64, 3])
# Text(0.5, 1.0, 'An image from training set')

# %% [markdown]
# ### (iii) Convert the `Dataset` into a `torch.utils.data.DataLoader`
#
# A DataLoader helps us to iterate trough the dataset em get a batch of samples each time.
#
# Relevant configuration parameters:
#
# ```python
# config["data_params"]["train_batch_size"]
# config["data_params"]["val_batch_size"]
# config["data_params"]["test_batch_size"]
# config["data_params"]["num_workers"]
# config["data_params"]["pin_memory"]
# ```

# %%
# Convert each 'Dataset' into a 'DataLoader'

from torch.utils.data import DataLoader

train_dataloader = DataLoader(
    dataset     = train_data,
    batch_size  = config["data_params"]["train_batch_size"],
    shuffle     = True,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

val_dataloader = DataLoader(
    dataset     = val_data,
    batch_size  = config["data_params"]["val_batch_size"],
    shuffle     = False,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

test_dataloader = DataLoader(
    dataset     = test_data,
    batch_size  = config["data_params"]["test_batch_size"],
    shuffle     = False,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

# %%
print(train_dataloader)
print(val_dataloader)
print(test_dataloader)

print(len(train_dataloader)) # returns the number of batches in a training epoch
print(len(val_dataloader))   # returns the number of batches in a validation epoch
print(len(test_dataloader))  # returns the number of batches in a test epoch
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fba04a0b250>
# <torch.utils.data.dataloader.DataLoader object at 0x7fba04a081d0>
# <torch.utils.data.dataloader.DataLoader object at 0x7fba056d0b10>
# 2544
# 311
# 139

# %%
# print metadata about a sample retrieved from the training DataLoader

imgs = next(iter(train_dataloader))

print(f'Batch of images shape: {imgs.shape}')   # BS, Ch, H, W
# Out:
# Batch of images shape: torch.Size([64, 3, 64, 64])

# %% [markdown]
# ## The VAE Model

# %%
class VanillaVAE(nn.Module):

    def __init__(
        self,
        in_channels: int,
        latent_dim:  int,
        hidden_dims: List = None,
        **kwargs
        ) -> None:

        super(VanillaVAE, self).__init__()

        self.latent_dim = latent_dim

        modules = []
        if hidden_dims is None:
            hidden_dims = [32, 64, 128, 256, 512]

        # Build the Encoder ...........................................

        # Define 5 blocks composed of: Conv2D -> BatchNorm2d -> LeakyReLU
        for h_dim in hidden_dims:
            modules.append(
                nn.Sequential(
                    nn.Conv2d(
                        in_channels,
                        out_channels = h_dim,
                        kernel_size  = 3,
                        stride       = 2, 
                        padding      = 1
                        ),
                    nn.BatchNorm2d(h_dim),
                    nn.LeakyReLU())
            )
            in_channels = h_dim

        # Add the 5 blocks to the encoder model
        self.encoder = nn.Sequential(*modules)

        # Fully connected layer that outputs the latent mean 
        self.fc_mu   = nn.Linear(
            in_features  = hidden_dims[-1]*4, 
            out_features = latent_dim
        )
        # Fully connected layer that outputs the latent log-variance 
        self.fc_var  = nn.Linear(
            in_features  = hidden_dims[-1]*4,
            out_features = latent_dim
        )

        # Build the Decoder ...........................................

        modules = []

        # Fully connected layer to make the latent variables to have the
        # correct shape for decoder
        self.decoder_input = nn.Linear(
            in_features  = latent_dim,
            out_features = hidden_dims[-1] * 4
        )

        # hidden_dims = [512, 256, 128, 64, 32]
        hidden_dims.reverse()

        # Define 4 blocks composed of: ConvTranspose2d -> BatchNorm2d -> LeakyReLU
        for i in range(len(hidden_dims) - 1):
            modules.append(
                nn.Sequential(
                    nn.ConvTranspose2d(
                        hidden_dims[i],
                        hidden_dims[i+1],
                        kernel_size    = 3,
                        stride         = 2,
                        padding        = 1,
                        output_padding = 1
                    ),
                    nn.BatchNorm2d(hidden_dims[i+1]),
                    nn.LeakyReLU())
            )

        # Add the 4 blocks to the decoder model
        self.decoder = nn.Sequential(*modules)

        # Add a final block to the decoder composed of:
        #   ConvTranspose2d -> BatchNorm2d -> LeakyReLU -> Conv2d -> Tanh
        self.final_layer = nn.Sequential(
            nn.ConvTranspose2d(
                hidden_dims[-1],
                hidden_dims[-1],
                kernel_size=3,
                stride=2,
                padding=1,
                output_padding=1
            ),
            nn.BatchNorm2d(hidden_dims[-1]),
            nn.LeakyReLU(),
            nn.Conv2d(
                hidden_dims[-1],
                out_channels = 3,
                kernel_size  = 3,
                padding      = 1
            ),
            nn.Sigmoid()
        )

    def encode(self, input: Tensor) -> List[Tensor]:
        """
        Encodes the input by passing through the encoder network
        and returns the latent mean and log-variance.

        Arguments:
            * input: Input tensor to encoder [N x C x H x W]
        Returns:
            A list containing the mean and the log-variance of latent distribution.
        """

        # Passes 'input' through the encoder
        result  = self.encoder(input)

        # Flatten the encoder output
        result  = torch.flatten(result, start_dim=1)

        # Split the result into the mean and variance
        # of the latent Normal distribution
        mu      = self.fc_mu(result)
        log_var = self.fc_var(result)

        return [mu, log_var]

    def decode(self, z: Tensor) -> Tensor:
        """
        Maps the given latent variable 'z' back to the image space.

        Arguments:
            * z: (Tensor) [B x D]
        Returns:
            * The image generated by the decoder,
              a tensor with shape [B x C x H x W].
        """
        # Reshape latent 'z' with the fully connected layer
        result = self.decoder_input(z)
        # Reorganize the latent dimensions
        result = result.view(-1, 512, 2, 2)
        # Pass data through the 4 decoder blocks
        result = self.decoder(result)
        # Pass data through the final block
        result = self.final_layer(result)
        return result

    def reparameterize(self, mu: Tensor, logvar: Tensor) -> Tensor:
        """
        Reparameterization trick to allow the gradient flow through
        the latent sampler. In this way, sampling 'z' from N(mu, var) is
        modified to sampling 'eps' from N(0,1) followed by the definition
        z = mu + eps * e^logvar.

        Arguments:
            * mu: Mean of the latent Normal distribution, a tensor [B x D]
            * logvar: Log-variance of the latent Normal distribution, a tensor [B x D]
        Returns:
            The latent variable 'z', a tensor [B x D].
        """
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps * std + mu

    def forward(self, input: Tensor, **kwargs) -> List[Tensor]:
        '''
        Defines the forward pass through the VAE: 
        encoder -> reparameterization -> decoder
        '''
        mu, log_var = self.encode(input)
        z           = self.reparameterize(mu, log_var)
        x           = self.decode(z)
        return  [x, input, mu, log_var]

    def loss_function(
        self,
        reconst_img: Tensor,
        input_img:   Tensor,
        mu:          Tensor,
        log_var:     Tensor,
        kld_weight:  float ) -> dict:
        '''
        Computes the VAE loss = reconstruction_loss + KLD_loss * kld_weight

        Arguments:
            * args
            * kwargs
        Returns:
            A tuple containing (loss, reconstruction term of loss, KLD term of loss)
        '''
        reconst_img  = reconst_img
        input_img    = input_img
        mu           = mu
        log_var      = log_var
        kld_weight   = kld_weight # Account for the minibatch samples from the dataset

        # Reconstruction term of the loss: SUM (x-x_reconstructed)^2
        reconst_loss = F.mse_loss(reconst_img, input_img, reduction='sum')

        # KL Divergence term of the loss
        #  D_KL(Normal(mu, var) || Normal(0, 1)) = -0.5 * [ log (var) + 1 - var^2 - mu^2 ]
        kld_loss = -0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp())

        # Loss = -ELBO
        batch_size    = mu.shape[0]
        reconst_loss /= batch_size
        kld_loss     /= batch_size
        loss = reconst_loss + kld_weight * kld_loss

        # print(f'Loss shape: {loss.shape} -> {loss}')

        return loss, reconst_loss, kld_loss

    def sample(
        self,
        num_samples:    int,
        current_device: int,
        **kwargs
        ) -> Tensor:
        """
        Samples the latent space and returns the corresponding reconstructed image.

        Arguments:
            * num_samples: Number of samples (an Int)
            * current_device: Device to run the model (an Int)
        Returns:
            The recontructed images given the samples (a tensor).
        """

        # Draw 'num_samples' samples from the standard Normal N(0,1)
        z = torch.randn(num_samples, self.latent_dim)

        # Put the sample in the same device of the model
        z = z.to(current_device)

        # Reconstruct 'num_samples' images from the samples that we draw
        samples = self.decode(z)

        return samples

    def generate(self, x: Tensor, **kwargs) -> Tensor:
        """
        Given input images 'x', passes them through the VAE and returns 
        the reconstructed images.

        Arguments:
            * x: Input images (a tensor [B x C x H x W]).
        Returns:
            The reconstructed images (a tensor [B x C x H x W]).
        """

        return self.forward(x)[0]

# %%
model = VanillaVAE(**config['model_params']).to(device)

model
# Out:
# VanillaVAE(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (fc_mu): Linear(in_features=2048, out_features=128, bias=True)
#   (fc_var): Linear(in_features=2048, out_features=128, bias=True)
#   (decoder_input): Linear(in_features=128, out_features=2048, bias=True)
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (final_layer): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Sigmoid()
#   )
# )

# %%
from torchinfo import summary

summary(model, input_size=(64, 3, 64, 64))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VanillaVAE                               [64, 3, 64, 64]           --
# ├─Sequential: 1-1                        [64, 512, 2, 2]           --
# │    └─Sequential: 2-1                   [64, 32, 32, 32]          --
# │    │    └─Conv2d: 3-1                  [64, 32, 32, 32]          896
# │    │    └─BatchNorm2d: 3-2             [64, 32, 32, 32]          64
# │    │    └─LeakyReLU: 3-3               [64, 32, 32, 32]          --
# │    └─Sequential: 2-2                   [64, 64, 16, 16]          --
# │    │    └─Conv2d: 3-4                  [64, 64, 16, 16]          18,496
# │    │    └─BatchNorm2d: 3-5             [64, 64, 16, 16]          128
# │    │    └─LeakyReLU: 3-6               [64, 64, 16, 16]          --
# │    └─Sequential: 2-3                   [64, 128, 8, 8]           --
# │    │    └─Conv2d: 3-7                  [64, 128, 8, 8]           73,856
# │    │    └─BatchNorm2d: 3-8             [64, 128, 8, 8]           256
# │    │    └─LeakyReLU: 3-9               [64, 128, 8, 8]           --
# │    └─Sequential: 2-4                   [64, 256, 4, 4]           --
# │    │    └─Conv2d: 3-10                 [64, 256, 4, 4]           295,168
# │    │    └─BatchNorm2d: 3-11            [64, 256, 4, 4]           512
# │    │    └─LeakyReLU: 3-12              [64, 256, 4, 4]           --
# │    └─Sequential: 2-5                   [64, 512, 2, 2]           --
# │    │    └─Conv2d: 3-13                 [64, 512, 2, 2]           1,180,160
# │    │    └─BatchNorm2d: 3-14            [64, 512, 2, 2]           1,024
# │    │    └─LeakyReLU: 3-15              [64, 512, 2, 2]           --
# ├─Linear: 1-2                            [64, 128]                 262,272
# ├─Linear: 1-3                            [64, 128]                 262,272
# ├─Linear: 1-4                            [64, 2048]                264,192
# ├─Sequential: 1-5                        [64, 32, 32, 32]          --
# │    └─Sequential: 2-6                   [64, 256, 4, 4]           --
# │    │    └─ConvTranspose2d: 3-16        [64, 256, 4, 4]           1,179,904
# │    │    └─BatchNorm2d: 3-17            [64, 256, 4, 4]           512
# │    │    └─LeakyReLU: 3-18              [64, 256, 4, 4]           --
# │    └─Sequential: 2-7                   [64, 128, 8, 8]           --
# │    │    └─ConvTranspose2d: 3-19        [64, 128, 8, 8]           295,040
# │    │    └─BatchNorm2d: 3-20            [64, 128, 8, 8]           256
# │    │    └─LeakyReLU: 3-21              [64, 128, 8, 8]           --
# │    └─Sequential: 2-8                   [64, 64, 16, 16]          --
# │    │    └─ConvTranspose2d: 3-22        [64, 64, 16, 16]          73,792
# │    │    └─BatchNorm2d: 3-23            [64, 64, 16, 16]          128
# │    │    └─LeakyReLU: 3-24              [64, 64, 16, 16]          --
# │    └─Sequential: 2-9                   [64, 32, 32, 32]          --
# │    │    └─ConvTranspose2d: 3-25        [64, 32, 32, 32]          18,464
# │    │    └─BatchNorm2d: 3-26            [64, 32, 32, 32]          64
# │    │    └─LeakyReLU: 3-27              [64, 32, 32, 32]          --
# ├─Sequential: 1-6                        [64, 3, 64, 64]           --
# │    └─ConvTranspose2d: 2-10             [64, 32, 64, 64]          9,248
# │    └─BatchNorm2d: 2-11                 [64, 32, 64, 64]          64
# │    └─LeakyReLU: 2-12                   [64, 32, 64, 64]          --
# │    └─Conv2d: 2-13                      [64, 3, 64, 64]           867
# │    └─Sigmoid: 2-14                     [64, 3, 64, 64]           --
# ==========================================================================================
# Total params: 3,937,635
# Trainable params: 3,937,635
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 8.81
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 269.62
# Params size (MB): 15.75
# Estimated Total Size (MB): 288.51
# ==========================================================================================

# %% [markdown]
# To test our model let us do a single forward pass (pass a sample batch from the training set through the model).

# %%
# 1. Get a batch of images from the training DataLoader

img_batch = next(iter(train_dataloader))

# 2. Get a single image from the batch and unsqueeze the image
#    so its shape fits the model

img_single = img_batch[0].unsqueeze(dim=0)
print(f"Single image shape: {img_single.shape}\n")

# 3. Perform a forward pass on a single image

model.eval()
with torch.inference_mode():
    img_out, img_in, mu_out, logvar_out = model(img_single.to(device))

# 4. Print output

print(f"Img output:\n{img_out}\n")
print(f"Mean:\n{mu_out}\n")
print(f"LogVar:\n{logvar_out}\n")
# Out:
# Single image shape: torch.Size([1, 3, 64, 64])
#
# Img output:
# tensor([[[[0.5135, 0.5165, 0.5161,  ..., 0.5163, 0.5161, 0.5149],
#           [0.5142, 0.5178, 0.5172,  ..., 0.5177, 0.5170, 0.5178],
#           [0.5138, 0.5180, 0.5170,  ..., 0.5180, 0.5171, 0.5175],
#           ...,
#           [0.5142, 0.5177, 0.5171,  ..., 0.5177, 0.5170, 0.5178],
#           [0.5138, 0.5182, 0.5172,  ..., 0.5181, 0.5172, 0.5177],
#           [0.5144, 0.5164, 0.5168,  ..., 0.5164, 0.5167, 0.5159]],
#
#          [[0.4927, 0.4938, 0.4943,  ..., 0.4939, 0.4941, 0.4948],
#           [0.4916, 0.4956, 0.4952,  ..., 0.4957, 0.4951, 0.4961],
#           [0.4923, 0.4952, 0.4959,  ..., 0.4953, 0.4958, 0.4953],
#           ...,
#           [0.4916, 0.4957, 0.4953,  ..., 0.4957, 0.4952, 0.4961],
#           [0.4925, 0.4951, 0.4959,  ..., 0.4951, 0.4957, 0.4953],
#           [0.4931, 0.4981, 0.4976,  ..., 0.4982, 0.4977, 0.4986]],
#
#          [[0.5085, 0.5079, 0.5083,  ..., 0.5080, 0.5085, 0.5092],
#           [0.5077, 0.5068, 0.5066,  ..., 0.5069, 0.5066, 0.5084],
#           [0.5075, 0.5070, 0.5076,  ..., 0.5068, 0.5070, 0.5083],
#           ...,
#           [0.5076, 0.5068, 0.5067,  ..., 0.5069, 0.5066, 0.5084],
#           [0.5076, 0.5071, 0.5071,  ..., 0.5070, 0.5071, 0.5083],
#           [0.5068, 0.5054, 0.5057,  ..., 0.5056, 0.5055, 0.5077]]]],
#        device='cuda:0')
#
# Mean:
# tensor([[ 0.0120, -0.0238, -0.0033,  0.0217, -0.0040, -0.0210,  0.0158, -0.0120,
#          -0.0116, -0.0304, -0.0053,  0.0263, -0.0037,  0.0233, -0.0143,  0.0027,
#           0.0167, -0.0182,  0.0248,  0.0059,  0.0374,  0.0170, -0.0094,  0.0001,
#           0.0262,  0.0157, -0.0192,  0.0019, -0.0026, -0.0223, -0.0079, -0.0253,
#           0.0031,  0.0184, -0.0085,  0.0175, -0.0002, -0.0088, -0.0137, -0.0194,
#           0.0009, -0.0099, -0.0011, -0.0295, -0.0196, -0.0084, -0.0113, -0.0257,
#           0.0268, -0.0168, -0.0245, -0.0166,  0.0010,  0.0018, -0.0003,  0.0064,
#           0.0078,  0.0136, -0.0093,  0.0088,  0.0078,  0.0074,  0.0056,  0.0212,
#          -0.0186, -0.0240, -0.0199, -0.0241,  0.0124,  0.0020, -0.0209,  0.0256,
#           0.0133, -0.0375,  0.0165,  0.0016,  0.0100,  0.0276,  0.0188, -0.0165,
#          -0.0046, -0.0019, -0.0161,  0.0169, -0.0177, -0.0117, -0.0192,  0.0140,
#           0.0090, -0.0062, -0.0037,  0.0249, -0.0062,  0.0272,  0.0036,  0.0268,
#          -0.0176, -0.0150,  0.0201,  0.0108, -0.0166, -0.0026,  0.0221, -0.0206,
#          -0.0020,  0.0096, -0.0011, -0.0162,  0.0158, -0.0218,  0.0103, -0.0202,
#           0.0213,  0.0214, -0.0320,  0.0105,  0.0217, -0.0215, -0.0094,  0.0136,
#          -0.0023, -0.0020, -0.0081, -0.0126, -0.0014, -0.0097, -0.0147, -0.0137]],
#        device='cuda:0')
#
# LogVar:
# tensor([[ 0.0121, -0.0016,  0.0279,  0.0308,  0.0176, -0.0042,  0.0030, -0.0096,
#          -0.0004,  0.0025,  0.0030, -0.0134,  0.0167,  0.0039,  0.0157,  0.0241,
#          -0.0009,  0.0190, -0.0339, -0.0159, -0.0033,  0.0033,  0.0110,  0.0092,
#          -0.0078,  0.0144,  0.0117, -0.0021,  0.0192, -0.0205,  0.0148, -0.0052,
#           0.0018, -0.0042,  0.0093,  0.0131, -0.0054, -0.0069, -0.0071,  0.0107,
#           0.0065, -0.0229,  0.0188, -0.0010,  0.0222, -0.0257,  0.0057,  0.0080,
#           0.0090,  0.0076,  0.0092,  0.0116,  0.0141, -0.0057,  0.0142, -0.0299,
#           0.0160,  0.0153, -0.0102, -0.0021, -0.0154,  0.0050,  0.0213, -0.0059,
#           0.0163, -0.0012,  0.0207, -0.0026, -0.0167, -0.0039,  0.0106, -0.0012,
#           0.0172, -0.0030, -0.0182,  0.0107, -0.0166, -0.0162, -0.0180, -0.0005,
#          -0.0252,  0.0101,  0.0097, -0.0085,  0.0093, -0.0264,  0.0120, -0.0156,
#           0.0047, -0.0130,  0.0128, -0.0252, -0.0114,  0.0090,  0.0204, -0.0029,
#           0.0137,  0.0051, -0.0232,  0.0007,  0.0080,  0.0246,  0.0149,  0.0066,
#           0.0163,  0.0270,  0.0067,  0.0183,  0.0097,  0.0170,  0.0130,  0.0138,
#           0.0130, -0.0299, -0.0047, -0.0124, -0.0265, -0.0106,  0.0227,  0.0211,
#           0.0123,  0.0273,  0.0030,  0.0008,  0.0040,  0.0066, -0.0170, -0.0122]],
#        device='cuda:0')

# %% [markdown]
# ## Creating `train_step()` and `val_step()` functions and `train()` to combine them
#
# Let us start by making `train_step()`.

# %%
def train_step(
    model:      torch.nn.Module,
    dataloader: torch.utils.data.DataLoader,
    loss_fn:    torch.nn.Module,
    optimizer:  torch.optim.Optimizer,
    kld_weight: float,
    epoch_id:   int,
    device:     torch.device,
    ) -> Tuple[float, float, float]:
    """
    Trains a PyTorch model for a single epoch.

    Turns a target PyTorch model to training mode and then
    runs through all of the required training steps (forward
    pass, loss calculation, optimizer step).

    Arguments:
        model:      A PyTorch model to be trained.
        dataloader: A DataLoader instance for the model to be trained on.
        loss_fn:    A PyTorch loss function to minimize.
        optimizer:  A PyTorch optimizer to help minimize the loss function.
        kld_weight: Weight to apply to the KLD term of the loss.
        device:     A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A tuple of training loss, reconstruction loss, kld loss.
        In the form (train_loss, reconst_loss, kld_loss). For example:

        (0.3456, 0.8743, 0.5678)
    """

    # Put model in train mode
    model.train()

    # Setup train loss, reconstruction loss, and KLD loss values
    train_loss         = 0.
    train_reconst_loss = 0.
    train_kld_loss     = 0.

    # Loop through data loader data batches
    for batch, X in enumerate(dataloader):
        # Send data to target device
        X = X.to(device)

        # 1. Forward pass
        X_out, _, mu_out, logvar_out = model(X)

        # 2. Calculate and accumulate losses
        loss, reconst_loss, kld_loss = loss_fn(
            X_out,
            X,
            mu_out,
            logvar_out,
            kld_weight,
        )

        train_loss         += loss.item()
        train_reconst_loss += reconst_loss.item()
        train_kld_loss     += kld_loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

    # Adjust losses to get average value per batch
    train_loss         = train_loss / len(dataloader)
    train_reconst_loss = train_reconst_loss / len(dataloader)
    train_kld_loss     = train_kld_loss / len(dataloader)

    return train_loss, train_reconst_loss, train_kld_loss

# %% [markdown]
# Now we will implement `val_step()`.

# %%
def val_step(
    model:      torch.nn.Module,
    dataloader: torch.utils.data.DataLoader,
    loss_fn:    torch.nn.Module,
    kld_weight: float,
    epoch_id:   int,
    device:     torch.device) -> Tuple[float, float, float]:
    """
    Runs a validation step with a PyTorch model for a single epoch.

    Turns a target PyTorch model to "eval" mode and then performs
    a forward pass on a testing dataset.

    Arguments:
        model:      A PyTorch model to be tested.
        dataloader: A DataLoader instance for the model to be tested on.
        loss_fn:    A PyTorch loss function to calculate loss on the test data.
        kld_weight: Weight to apply to the KLD term of the loss.
        device:     A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A tuple of validation loss, reconstruction loss, kld loss.
        In the form (train_loss, reconst_loss, kld_loss). For example:

        (0.3456, 0.8743, 0.5678)
    """
    # Put model in eval mode
    model.eval()

    # Setup validation loss, reconstruction loss, and KLD loss values
    val_loss         = 0.
    val_reconst_loss = 0.
    val_kld_loss     = 0.

    # Turn on inference context manager
    with torch.inference_mode():

        # Loop through DataLoader batches
        for batch, X in enumerate(dataloader):

            # Send data to target device
            X = X.to(device)

            # 1. Forward pass
            X_out, _, mu_out, logvar_out = model(X)

            # 2. Calculate and accumulate losses
            loss, reconst_loss, kld_loss = loss_fn(
                X_out,
                X,
                mu_out,
                logvar_out,
                kld_weight,
            )

            val_loss         += loss.item()
            val_reconst_loss += reconst_loss.item()
            val_kld_loss     += kld_loss.item()

    # Adjust losses to get average value per batch
    val_loss         = val_loss / len(dataloader)
    val_reconst_loss = val_reconst_loss / len(dataloader)
    val_kld_loss     = val_kld_loss / len(dataloader)

    return val_loss, val_reconst_loss, val_kld_loss

# %% [markdown]
# And we will combine `train_step()` and `val_step()` into `train()`.

# %%
from tqdm.auto import tqdm

def train(
    model: torch.nn.Module,
    train_dataloader: torch.utils.data.DataLoader,
    val_dataloader:   torch.utils.data.DataLoader,
    optimizer:        torch.optim.Optimizer,
    loss_fn:          torch.nn.Module,
    kld_weight:       float,
    epochs:           int,
    device:           torch.device ) -> Dict[str, List[float]]:
    """
    Trains and validates a PyTorch model.

    Passes a target PyTorch models through train_step() and val_step()
    functions for a number of epochs, training and validating the model
    in the same epoch loop.

    Calculates, prints and stores evaluation metrics throughout.

    Arguments:
        model:            A PyTorch model to be trained and tested.
        train_dataloader: A DataLoader instance for the model to be trained on.
        val_dataloader:   A DataLoader instance for the model to be tested on.
        optimizer:        A PyTorch optimizer to help minimize the loss function.
        loss_fn:          A PyTorch loss function to calculate loss on both datasets.
        kld_weight:       Weight to apply to the KLD term of the loss.
        epochs:           An integer indicating how many epochs to train for.
        device:           A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A dictionary of training and validation losses. Each metric has a value 
        in a list for each epoch.
        In the form:
            {
            train_loss:         [...],
            train_reconst_loss: [...],
            train_kld_loss:     [...],
            val_loss:           [...],
            val_reconst_loss:   [...],
            val_kld_loss:       [...]
            }
        For example if training for epochs=2:
            {
            train_loss:         [2.0616, 1.0537],
            train_reconst_loss: [0.3945, 0.4945],
            train_kld_loss:     [0.5945, 0.6945],
            val_loss:           [1.2641, 1.5706],
            val_reconst_loss:   [0.7400, 0.8973],
            val_kld_loss:       [0.9945, 0.0545],
            }
    """

    # Create empty results dictionary
    results = {
        "train_loss":         [],
        "train_reconst_loss": [],
        "train_kld_loss":     [],
        "val_loss":           [],
        "val_reconst_loss":   [],
        "val_kld_loss":       []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):

        train_loss, train_rec_loss, train_kld_loss = train_step(
            model      = model,
            dataloader = train_dataloader,
            loss_fn    = loss_fn,
            optimizer  = optimizer,
            kld_weight = kld_weight,
            epoch_id   = epoch,
            device     = device,
        )

        val_loss, val_rec_loss, val_kld_loss = val_step(
            model      = model,
            dataloader = test_dataloader,
            loss_fn    = loss_fn,
            kld_weight = kld_weight,
            epoch_id   = epoch,
            device     = device
        )

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"Losses-> train: {train_loss:.4f} | "
            f"train_rec: {train_rec_loss:.4f} | "
            f"train_kld: {train_kld_loss:.4f} | "
            f"val: {val_loss:.4f} | "
            f"val_rec: {val_rec_loss:.4f} | "
            f"val_kld: {val_kld_loss:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_reconst_loss"].append(train_rec_loss)
        results["train_kld_loss"].append(train_kld_loss)
        results["val_loss"].append(val_loss)
        results["val_reconst_loss"].append(val_rec_loss)
        results["val_kld_loss"].append(val_kld_loss)

        # Log metrics to W&B
        wandb.log(
            {
            "train_loss":     train_loss,
            "train_rec_loss": train_rec_loss,
            "train_kld_loss": train_kld_loss,
            "val_loss":       val_loss,
            "val_rec_loss":   val_rec_loss,
            "val_kld_loss":   val_kld_loss,
            "epoch":          epoch,
            }
        )

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ## Create a function to save the model
#
# Let us setup a function to save our model to a directory.

# %%
from pathlib import Path

def save_model(
    model: torch.nn.Module,
    target_dir: str,
    model_name: str ):
    """
    Saves a PyTorch model to a target directory.

    Args:
        model:      A target PyTorch model to save.
        target_dir: A directory for saving the model to.
        model_name: A filename for the saved model. Should include
                    either ".pth" or ".pt" as the file extension.

    Example of usage:
        save_model(
            model=model_0,
            target_dir="models",
            model_name="05_going_modular_tingvgg_model.pth"
        )
    """
    # Create target directory
    target_dir_path = Path(target_dir)
    target_dir_path.mkdir(parents=True, exist_ok=True)

    # Create model save path
    assert model_name.endswith(".pth") or model_name.endswith(".pt"), "model_name should end with '.pt' or '.pth'"
    model_save_path = target_dir_path / model_name

    # Save the model state_dict()
    print(f"[INFO] Saving model to: {model_save_path}")
    torch.save(
        obj = model.state_dict(),
        f   = model_save_path
    )

# %% [markdown]
# ## Train, validate and save the model
#
# Let us leverage the functions we have got above to train, validate and save a model to file.

# %%
# Set random seeds

torch.manual_seed(config["exp_params"]["manual_seed"])
torch.cuda.manual_seed(config["exp_params"]["manual_seed"])

# Recreate an instance of VanillaVAE

model_vae = VanillaVAE(**config['model_params']).to(device)

# Setup loss function and optimizer

loss_fn = model_vae.loss_function

optimizer = torch.optim.Adam(
    params = model_vae.parameters(), 
    lr     = config["exp_params"]["LR"]
)

# Tell wandb to watch what the model gets up to: gradients, weights, and more
#
#wandb.watch(model_vae, loss_fn, log="all", log_freq=10)

# Start the timer

from timeit import default_timer as timer
start_time = timer()

# Train model_vae

vae_results = train(model=model_vae,
    train_dataloader = train_dataloader,
    val_dataloader   = val_dataloader,
    optimizer        = optimizer,
    loss_fn          = loss_fn,
    kld_weight       = config["exp_params"]["kld_weight"],
    epochs           = config["exp_params"]["epochs"],
    device           = device
)

# End the timer and print out how long it took

end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")

# Save the model to file

save_model(model=model_vae,
    target_dir = "models",
    model_name = f"{BASE_FILE_NAME}.pth"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | Losses-> train: 225.2684 | train_rec: 177.1515 | train_kld: 48.1169 | val: 188.0862 | val_rec: 137.1099 | val_kld: 50.9762
# Epoch: 2 | Losses-> train: 185.5237 | train_rec: 134.2978 | train_kld: 51.2259 | val: 176.5799 | val_rec: 124.5201 | val_kld: 52.0597
# Epoch: 3 | Losses-> train: 179.3207 | train_rec: 126.9209 | train_kld: 52.3998 | val: 178.4293 | val_rec: 125.7023 | val_kld: 52.7270
# Epoch: 4 | Losses-> train: 176.1383 | train_rec: 123.1330 | train_kld: 53.0053 | val: 176.7087 | val_rec: 124.9761 | val_kld: 51.7326
# Epoch: 5 | Losses-> train: 173.5591 | train_rec: 120.1846 | train_kld: 53.3745 | val: 169.9532 | val_rec: 118.0870 | val_kld: 51.8661
# Epoch: 6 | Losses-> train: 171.6883 | train_rec: 118.0597 | train_kld: 53.6286 | val: 166.9871 | val_rec: 114.7584 | val_kld: 52.2287
# Epoch: 7 | Losses-> train: 170.2550 | train_rec: 116.4221 | train_kld: 53.8328 | val: 166.6504 | val_rec: 112.3619 | val_kld: 54.2885
# Epoch: 8 | Losses-> train: 169.3923 | train_rec: 115.3933 | train_kld: 53.9991 | val: 165.2792 | val_rec: 111.5960 | val_kld: 53.6832
# Epoch: 9 | Losses-> train: 168.5089 | train_rec: 114.3344 | train_kld: 54.1745 | val: 165.9302 | val_rec: 112.7979 | val_kld: 53.1323
# Epoch: 10 | Losses-> train: 167.7264 | train_rec: 113.4396 | train_kld: 54.2869 | val: 163.9213 | val_rec: 110.5717 | val_kld: 53.3497
# Epoch: 11 | Losses-> train: 166.8928 | train_rec: 112.5009 | train_kld: 54.3920 | val: 163.0334 | val_rec: 109.3482 | val_kld: 53.6853
# Epoch: 12 | Losses-> train: 166.5157 | train_rec: 111.9898 | train_kld: 54.5259 | val: 164.3108 | val_rec: 111.4073 | val_kld: 52.9035
# Epoch: 13 | Losses-> train: 165.9257 | train_rec: 111.2772 | train_kld: 54.6485 | val: 162.2602 | val_rec: 108.5082 | val_kld: 53.7520
# Epoch: 14 | Losses-> train: 165.3519 | train_rec: 110.6398 | train_kld: 54.7121 | val: 163.9197 | val_rec: 110.6010 | val_kld: 53.3187
# Epoch: 15 | Losses-> train: 164.9497 | train_rec: 110.1917 | train_kld: 54.7580 | val: 161.8318 | val_rec: 107.8424 | val_kld: 53.9895
# Epoch: 16 | Losses-> train: 164.5262 | train_rec: 109.7080 | train_kld: 54.8182 | val: 163.1410 | val_rec: 110.1848 | val_kld: 52.9562
# Epoch: 17 | Losses-> train: 164.1047 | train_rec: 109.2141 | train_kld: 54.8906 | val: 161.5435 | val_rec: 107.0369 | val_kld: 54.5066
# Epoch: 18 | Losses-> train: 163.7545 | train_rec: 108.8083 | train_kld: 54.9462 | val: 161.0506 | val_rec: 107.4004 | val_kld: 53.6503
# Epoch: 19 | Losses-> train: 163.4790 | train_rec: 108.4931 | train_kld: 54.9859 | val: 160.6154 | val_rec: 106.0434 | val_kld: 54.5720
# Epoch: 20 | Losses-> train: 163.1459 | train_rec: 108.1174 | train_kld: 55.0286 | val: 161.0163 | val_rec: 107.2061 | val_kld: 53.8102
# Epoch: 21 | Losses-> train: 162.8405 | train_rec: 107.7691 | train_kld: 55.0714 | val: 160.2423 | val_rec: 105.8795 | val_kld: 54.3629
# Epoch: 22 | Losses-> train: 162.5333 | train_rec: 107.3792 | train_kld: 55.1541 | val: 160.6681 | val_rec: 106.1381 | val_kld: 54.5300
# Epoch: 23 | Losses-> train: 162.2279 | train_rec: 107.0351 | train_kld: 55.1928 | val: 159.8073 | val_rec: 105.4576 | val_kld: 54.3497
# Epoch: 24 | Losses-> train: 161.9576 | train_rec: 106.6617 | train_kld: 55.2959 | val: 159.2238 | val_rec: 104.9658 | val_kld: 54.2580
# Epoch: 25 | Losses-> train: 161.7017 | train_rec: 106.3744 | train_kld: 55.3273 | val: 159.7773 | val_rec: 105.3849 | val_kld: 54.3924
# Epoch: 26 | Losses-> train: 161.4523 | train_rec: 106.0977 | train_kld: 55.3546 | val: 160.0529 | val_rec: 105.7096 | val_kld: 54.3433
# Epoch: 27 | Losses-> train: 161.2848 | train_rec: 105.9040 | train_kld: 55.3809 | val: 159.3981 | val_rec: 104.5538 | val_kld: 54.8444
# Epoch: 28 | Losses-> train: 161.1013 | train_rec: 105.6476 | train_kld: 55.4537 | val: 159.2407 | val_rec: 104.4835 | val_kld: 54.7572
# Epoch: 29 | Losses-> train: 160.9760 | train_rec: 105.5140 | train_kld: 55.4620 | val: 158.5379 | val_rec: 104.0278 | val_kld: 54.5101
# Epoch: 30 | Losses-> train: 160.7273 | train_rec: 105.2304 | train_kld: 55.4969 | val: 158.8392 | val_rec: 104.4743 | val_kld: 54.3649
# Epoch: 31 | Losses-> train: 160.5295 | train_rec: 105.0199 | train_kld: 55.5096 | val: 158.2684 | val_rec: 103.7155 | val_kld: 54.5529
# Epoch: 32 | Losses-> train: 160.4590 | train_rec: 104.9301 | train_kld: 55.5289 | val: 158.5981 | val_rec: 104.4354 | val_kld: 54.1627
# Epoch: 33 | Losses-> train: 160.3823 | train_rec: 104.8364 | train_kld: 55.5458 | val: 158.4594 | val_rec: 104.3508 | val_kld: 54.1087
# Epoch: 34 | Losses-> train: 160.2279 | train_rec: 104.6549 | train_kld: 55.5731 | val: 158.3392 | val_rec: 103.9529 | val_kld: 54.3863
# Epoch: 35 | Losses-> train: 160.0722 | train_rec: 104.4739 | train_kld: 55.5984 | val: 159.0480 | val_rec: 104.4275 | val_kld: 54.6205
# Epoch: 36 | Losses-> train: 159.9370 | train_rec: 104.3342 | train_kld: 55.6028 | val: 158.1018 | val_rec: 103.1606 | val_kld: 54.9412
# Epoch: 37 | Losses-> train: 159.8534 | train_rec: 104.2351 | train_kld: 55.6183 | val: 157.9915 | val_rec: 103.0255 | val_kld: 54.9660
# Epoch: 38 | Losses-> train: 159.7197 | train_rec: 104.0757 | train_kld: 55.6440 | val: 157.3059 | val_rec: 102.7866 | val_kld: 54.5193
# Epoch: 39 | Losses-> train: 159.5920 | train_rec: 103.9162 | train_kld: 55.6758 | val: 158.2024 | val_rec: 103.2284 | val_kld: 54.9740
# Epoch: 40 | Losses-> train: 159.4621 | train_rec: 103.8020 | train_kld: 55.6601 | val: 157.8724 | val_rec: 102.9713 | val_kld: 54.9011
# Epoch: 41 | Losses-> train: 159.4014 | train_rec: 103.7054 | train_kld: 55.6960 | val: 157.6313 | val_rec: 102.4910 | val_kld: 55.1403
# Epoch: 42 | Losses-> train: 159.3024 | train_rec: 103.6169 | train_kld: 55.6856 | val: 157.8987 | val_rec: 102.7694 | val_kld: 55.1293
# Epoch: 43 | Losses-> train: 159.1309 | train_rec: 103.4397 | train_kld: 55.6912 | val: 157.4089 | val_rec: 102.7848 | val_kld: 54.6241
# Epoch: 44 | Losses-> train: 159.1215 | train_rec: 103.4164 | train_kld: 55.7051 | val: 157.2513 | val_rec: 101.8445 | val_kld: 55.4068
# Epoch: 45 | Losses-> train: 159.0497 | train_rec: 103.3004 | train_kld: 55.7493 | val: 157.4314 | val_rec: 102.3092 | val_kld: 55.1221
# Epoch: 46 | Losses-> train: 159.0064 | train_rec: 103.2883 | train_kld: 55.7181 | val: 157.5711 | val_rec: 103.4750 | val_kld: 54.0961
# Epoch: 47 | Losses-> train: 158.9111 | train_rec: 103.1432 | train_kld: 55.7679 | val: 157.1366 | val_rec: 102.2861 | val_kld: 54.8504
# Epoch: 48 | Losses-> train: 158.8109 | train_rec: 103.0481 | train_kld: 55.7628 | val: 157.0840 | val_rec: 101.5893 | val_kld: 55.4947
# Epoch: 49 | Losses-> train: 158.7154 | train_rec: 102.9589 | train_kld: 55.7565 | val: 156.8603 | val_rec: 101.8808 | val_kld: 54.9795
# Epoch: 50 | Losses-> train: 158.6548 | train_rec: 102.9036 | train_kld: 55.7512 | val: 156.9366 | val_rec: 102.2214 | val_kld: 54.7152
# Epoch: 51 | Losses-> train: 158.5403 | train_rec: 102.7569 | train_kld: 55.7834 | val: 157.3445 | val_rec: 102.9185 | val_kld: 54.4260
# Epoch: 52 | Losses-> train: 158.5013 | train_rec: 102.7238 | train_kld: 55.7776 | val: 157.2615 | val_rec: 102.5892 | val_kld: 54.6724
# Epoch: 53 | Losses-> train: 158.3871 | train_rec: 102.6024 | train_kld: 55.7846 | val: 156.9047 | val_rec: 101.9126 | val_kld: 54.9922
# Epoch: 54 | Losses-> train: 158.3415 | train_rec: 102.5375 | train_kld: 55.8041 | val: 156.6159 | val_rec: 101.4241 | val_kld: 55.1918
# Epoch: 55 | Losses-> train: 158.3371 | train_rec: 102.5013 | train_kld: 55.8358 | val: 156.5166 | val_rec: 101.5276 | val_kld: 54.9891
# Epoch: 56 | Losses-> train: 158.2445 | train_rec: 102.4272 | train_kld: 55.8173 | val: 156.8639 | val_rec: 102.5678 | val_kld: 54.2961
# Epoch: 57 | Losses-> train: 158.1696 | train_rec: 102.3945 | train_kld: 55.7750 | val: 156.7306 | val_rec: 102.5442 | val_kld: 54.1863
# Epoch: 58 | Losses-> train: 158.0751 | train_rec: 102.2368 | train_kld: 55.8383 | val: 156.3557 | val_rec: 101.4208 | val_kld: 54.9349
# Epoch: 59 | Losses-> train: 158.0858 | train_rec: 102.2471 | train_kld: 55.8387 | val: 156.7584 | val_rec: 102.3372 | val_kld: 54.4213
# Epoch: 60 | Losses-> train: 158.0292 | train_rec: 102.1664 | train_kld: 55.8628 | val: 156.5186 | val_rec: 101.6975 | val_kld: 54.8210
# Epoch: 61 | Losses-> train: 157.9378 | train_rec: 102.0905 | train_kld: 55.8474 | val: 156.5499 | val_rec: 101.8590 | val_kld: 54.6909
# Epoch: 62 | Losses-> train: 157.8878 | train_rec: 102.0497 | train_kld: 55.8381 | val: 156.4832 | val_rec: 101.1175 | val_kld: 55.3656
# Epoch: 63 | Losses-> train: 157.8265 | train_rec: 101.9745 | train_kld: 55.8519 | val: 156.1416 | val_rec: 101.2274 | val_kld: 54.9142
# Epoch: 64 | Losses-> train: 157.7659 | train_rec: 101.9205 | train_kld: 55.8454 | val: 156.5853 | val_rec: 100.6486 | val_kld: 55.9367
# Epoch: 65 | Losses-> train: 157.6502 | train_rec: 101.8440 | train_kld: 55.8062 | val: 155.9568 | val_rec: 100.7373 | val_kld: 55.2195
# Epoch: 66 | Losses-> train: 157.5780 | train_rec: 101.7384 | train_kld: 55.8396 | val: 156.5594 | val_rec: 101.8616 | val_kld: 54.6978
# Epoch: 67 | Losses-> train: 157.5757 | train_rec: 101.7073 | train_kld: 55.8684 | val: 155.9485 | val_rec: 100.9215 | val_kld: 55.0269
# Epoch: 68 | Losses-> train: 157.4998 | train_rec: 101.6578 | train_kld: 55.8421 | val: 156.2128 | val_rec: 101.7134 | val_kld: 54.4994
# Epoch: 69 | Losses-> train: 157.4637 | train_rec: 101.5896 | train_kld: 55.8740 | val: 156.0147 | val_rec: 101.2713 | val_kld: 54.7434
# Epoch: 70 | Losses-> train: 157.4317 | train_rec: 101.5849 | train_kld: 55.8468 | val: 156.3459 | val_rec: 101.4496 | val_kld: 54.8964
# Epoch: 71 | Losses-> train: 157.4017 | train_rec: 101.5278 | train_kld: 55.8739 | val: 156.3196 | val_rec: 101.5280 | val_kld: 54.7916
# Epoch: 72 | Losses-> train: 157.3024 | train_rec: 101.4177 | train_kld: 55.8846 | val: 156.0578 | val_rec: 100.9709 | val_kld: 55.0869
# Epoch: 73 | Losses-> train: 157.2987 | train_rec: 101.4212 | train_kld: 55.8775 | val: 156.8123 | val_rec: 101.9294 | val_kld: 54.8829
# Epoch: 74 | Losses-> train: 157.2981 | train_rec: 101.4048 | train_kld: 55.8932 | val: 156.0330 | val_rec: 100.8835 | val_kld: 55.1495
# Epoch: 75 | Losses-> train: 157.2670 | train_rec: 101.3666 | train_kld: 55.9003 | val: 156.2097 | val_rec: 101.0658 | val_kld: 55.1440
# Epoch: 76 | Losses-> train: 157.1787 | train_rec: 101.2967 | train_kld: 55.8819 | val: 155.7753 | val_rec: 100.7039 | val_kld: 55.0715
# Epoch: 77 | Losses-> train: 157.1638 | train_rec: 101.2384 | train_kld: 55.9255 | val: 156.0218 | val_rec: 100.5928 | val_kld: 55.4290
# Epoch: 78 | Losses-> train: 157.0818 | train_rec: 101.1902 | train_kld: 55.8915 | val: 155.6046 | val_rec: 101.1799 | val_kld: 54.4248
# Epoch: 79 | Losses-> train: 157.0782 | train_rec: 101.1435 | train_kld: 55.9347 | val: 155.7013 | val_rec: 100.3360 | val_kld: 55.3653
# Epoch: 80 | Losses-> train: 157.0253 | train_rec: 101.1042 | train_kld: 55.9211 | val: 156.6336 | val_rec: 102.7146 | val_kld: 53.9190
# Epoch: 81 | Losses-> train: 157.0055 | train_rec: 101.1049 | train_kld: 55.9007 | val: 155.8817 | val_rec: 101.0937 | val_kld: 54.7880
# Epoch: 82 | Losses-> train: 156.9800 | train_rec: 101.0552 | train_kld: 55.9248 | val: 155.4599 | val_rec: 99.6814 | val_kld: 55.7785
# Epoch: 83 | Losses-> train: 156.9566 | train_rec: 101.0150 | train_kld: 55.9416 | val: 155.5492 | val_rec: 100.3349 | val_kld: 55.2143
# Epoch: 84 | Losses-> train: 156.8925 | train_rec: 100.9620 | train_kld: 55.9304 | val: 155.4893 | val_rec: 100.1911 | val_kld: 55.2982
# Epoch: 85 | Losses-> train: 156.8316 | train_rec: 100.9236 | train_kld: 55.9079 | val: 155.7733 | val_rec: 100.7571 | val_kld: 55.0162
# Epoch: 86 | Losses-> train: 156.8291 | train_rec: 100.8924 | train_kld: 55.9367 | val: 156.1069 | val_rec: 100.7602 | val_kld: 55.3467
# Epoch: 87 | Losses-> train: 156.7297 | train_rec: 100.8144 | train_kld: 55.9153 | val: 155.2623 | val_rec: 99.6062 | val_kld: 55.6561
# Epoch: 88 | Losses-> train: 156.7463 | train_rec: 100.8058 | train_kld: 55.9405 | val: 155.4206 | val_rec: 100.4923 | val_kld: 54.9283
# Epoch: 89 | Losses-> train: 156.6964 | train_rec: 100.7804 | train_kld: 55.9160 | val: 155.6497 | val_rec: 100.1296 | val_kld: 55.5201
# Epoch: 90 | Losses-> train: 156.6809 | train_rec: 100.7569 | train_kld: 55.9240 | val: 155.2306 | val_rec: 99.7068 | val_kld: 55.5239
# Epoch: 91 | Losses-> train: 156.6671 | train_rec: 100.7459 | train_kld: 55.9211 | val: 155.8134 | val_rec: 100.4848 | val_kld: 55.3286
# Epoch: 92 | Losses-> train: 156.5682 | train_rec: 100.6350 | train_kld: 55.9332 | val: 155.6786 | val_rec: 100.2928 | val_kld: 55.3858
# Epoch: 93 | Losses-> train: 156.6137 | train_rec: 100.6621 | train_kld: 55.9517 | val: 155.2969 | val_rec: 100.2630 | val_kld: 55.0339
# Epoch: 94 | Losses-> train: 156.5522 | train_rec: 100.6103 | train_kld: 55.9420 | val: 155.2155 | val_rec: 100.0488 | val_kld: 55.1668
# Epoch: 95 | Losses-> train: 156.5007 | train_rec: 100.6017 | train_kld: 55.8990 | val: 155.0335 | val_rec: 99.6272 | val_kld: 55.4063
# Epoch: 96 | Losses-> train: 156.5083 | train_rec: 100.5458 | train_kld: 55.9625 | val: 155.1644 | val_rec: 99.4635 | val_kld: 55.7008
# Epoch: 97 | Losses-> train: 156.4101 | train_rec: 100.4745 | train_kld: 55.9356 | val: 155.1926 | val_rec: 100.5118 | val_kld: 54.6807
# Epoch: 98 | Losses-> train: 156.3785 | train_rec: 100.4479 | train_kld: 55.9306 | val: 155.3285 | val_rec: 100.8183 | val_kld: 54.5103
# Epoch: 99 | Losses-> train: 156.3911 | train_rec: 100.4454 | train_kld: 55.9457 | val: 155.3841 | val_rec: 100.3772 | val_kld: 55.0069
# Epoch: 100 | Losses-> train: 156.3741 | train_rec: 100.4294 | train_kld: 55.9447 | val: 155.0593 | val_rec: 99.8448 | val_kld: 55.2145
# [INFO] Total training time: 5755.430 seconds
# [INFO] Saving model to: models/VAE_CelebA_64x64_04.pth

# %% [markdown]
# ## Save results to a CSV file
#
# Convert the `vae_results` dictionary, containing list with the loss values, to a DataFrame and later to a CSV file.

# %%
vae_results_df = pd.concat({k: pd.Series(v) for k, v in vae_results.items()}, axis=1)

vae_results_df.to_csv(
    f"results/{BASE_FILE_NAME}_results.csv",
    sep=',',
    index=False,
    encoding='utf-8'
)

# %% [markdown]
# ## Plot the training and validation losses

# %%
vae_results_df[["train_loss", "train_reconst_loss", "train_kld_loss"]].plot()
vae_results_df[["val_loss", "val_reconst_loss", "val_kld_loss"]].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Reconstruct images drawn from the test set and generate new images given samples from the latent distribution

# %%
from torchvision.utils import save_image

def reconstruct_sample_images(
    model:             torch.nn.Module,
    test_dataloader:   torch.utils.data.DataLoader,
    file_inputs:       Union[str, Path],
    file_reconstructs: Union[str, Path],
    file_samples:      Union[str, Path],
    device:            torch.device
    ):
    '''
    Get a batch of images from test DataLoader, pass them through the model 
    and save the reconstructed images to file.
    Get 144 samples from latent distribution, generate the correspondent images
    and save the images to file.

    Arguments:
        model:             The PyTorch model. 
        test_dataloader:   The test DataLoader to get the images that 
                           will be used in reconstruction.
        file_inputs:       File/Path to save the batch of input images used in reconstruction.
        file_reconstructs: File/Path to save the batch of reconstructed images.
        file_samples:      File/Path to save the 144 generated images.
        device:            A target device where the model is located (e.g. "cuda" or "cpu").
    '''
    # Get a batch of images from the test Dataloader that will be used in reconstruction
    input_img = next(iter(test_dataloader))

    # Save the batch of images retrieved from the test Dataloader to a file
    save_image(
        input_img.data,
        file_inputs,
        normalize = True,
        nrow      = 12
    )

    # Pass the batch of images through the model
    input_img = input_img.to(device)
    recons_img = model.generate(input_img)

    # Save the reconstructed images to a file
    save_image(
        recons_img.cpu().data,
        file_reconstructs,
        normalize = True,
        nrow      = 12
    )

    try:
        # Get 144 samples from the latent distribution 
        # and pass them through the decoder <=> generate images
        generated_img = model.sample(144, device)

        # Save the generated images to a file
        save_image(
            generated_img.cpu().data, 
            file_samples,
            normalize=True,
            nrow=12
        )
    except Warning:
        pass

# %%
reconstruct_sample_images(
    model_vae,
    test_dataloader,
    file_inputs       = f"results/{BASE_FILE_NAME}_input.jpg",
    file_reconstructs = f"results/{BASE_FILE_NAME}_reconstructed.jpg",
    file_samples      = f"results/{BASE_FILE_NAME}_generated.jpg",
    device            = device,
)

# %%
def reconstruct_sample_images_v2(
    model:             torch.nn.Module,
    test_dataloader:   torch.utils.data.DataLoader,
    file_inputs:       Union[str, Path],
    file_reconstructs: Union[str, Path],
    file_samples:      Union[str, Path],
    nrows:             int,
    ncols:             int,
    device:            torch.device
    ):
    '''
    Get a batch of images from test DataLoader and pass them through the model.
    Among the batch of input images, save a grid of nrowsxncols images to a file.
    Among the batch of reconstructed images, save a grid of nrowsxncols images to a file.
    Get 144 samples from latent distribution, generate the correspondent images
    and save a grid of nrowsxncols generated images to file.

    Arguments:
        model:             The PyTorch model. 
        test_dataloader:   The test DataLoader to get the images that 
                           will be used in reconstruction.
        file_inputs:       File/Path to save the batch of input images used in reconstruction.
        file_reconstructs: File/Path to save the batch of reconstructed images.
        file_samples:      File/Path to save the 144 generated images.
        nrows:             Number of rowns of images to save to the files.
        nvols:             Number of columnss of images to save to the files.
        device:            A target device where the model is located (e.g. "cuda" or "cpu").
    '''
    # Get a batch of images from the test Dataloader that will be used in reconstruction
    input_img = next(iter(test_dataloader))

    assert nrows*ncols <= len(input_img), f"{nrows*ncols} must be less or equal to thebatch size ({len(input_img)})"

    # Save the batch of images retrieved from the test Dataloader to a file
    save_image(
        input_img[0:nrows*ncols].data,
        file_inputs,
        normalize = True,
        nrow      = ncols,
    )

    # Pass the batch of images through the model
    input_img  = input_img.to(device)
    recons_img = model.generate(input_img)

    # Save the reconstructed images to a file
    save_image(
        recons_img[0:nrows*ncols].cpu().data,
        file_reconstructs,
        normalize = True,
        nrow      = ncols,
    )

    try:
        # Get 144 samples from the latent distribution 
        # and pass them through the decoder <=> generate images
        generated_img = model.sample(144, device)

        # Save the generated images to a file
        save_image(
            generated_img[0:nrows*ncols].cpu().data, 
            file_samples,
            normalize=True,
            nrow=ncols,
        )
    except Warning:
        pass

# %%
reconstruct_sample_images_v2(
    model_vae,
    test_dataloader,
    file_inputs       = f"results/{BASE_FILE_NAME}_input_8x4.jpg",
    file_reconstructs = f"results/{BASE_FILE_NAME}_reconstructed_8x4.jpg",
    file_samples      = f"results/{BASE_FILE_NAME}_generated_8x4.jpg",
    nrows             = 8,
    ncols             = 4,
    device            = device,
)

# %% [markdown]
# ## Results
#
# Input images:
# ![](results/vae_antixz_64x64_input.jpg)

# %% [markdown]
# Reconstructed images:
# ![](results/vae_antixz_64x64_reconstructed.jpg)

# %% [markdown]
# Generated new images:
# ![](results/vae_antixz_64x64_generated.jpg)
