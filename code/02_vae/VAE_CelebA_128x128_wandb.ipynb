# %% [markdown]
# # Variational Autoencoder applied to CelebA Dataset
#
# The VAE model was adapted from https://github.com/AntixK/PyTorch-VAE/.
#
# The model was trained on the CelebA dataset: http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html
#
# Images were resized to 64x64 pixels.
#
# Antonio Esteves @ UMinho, Mar 2024

# %% [markdown]
# ## Import necessary libraries

# %%
import os
from   pathlib  import Path
import pandas   as     pd
import torch
import torch.nn as     nn
from   torch.nn import functional as F
from   typing   import List, TypeVar, Tuple, Dict, Union #  Callable, Any, Optional, Sequence

Tensor = TypeVar('torch.tensor')

# %% [markdown]
# ## Import W&B and Login

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: ajesteves. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Read the configuration file

# %%
import yaml

BASE_FILE_NAME = "VAE_CelebA_128x128_04"
CONFIG_FILE    = 'config/vae_antixk_config2.yaml'

with open(CONFIG_FILE, 'r') as file:
    try:
        config = yaml.safe_load(file)
    except yaml.YAMLError as exc:
        print(exc)

# %%
config
# Out:
# {'model_params': {'name': 'VAE_128x128', 'in_channels': 3, 'latent_dim': 192},
#  'data_params': {'data_path': '/home/datasets/celeba',
#   'train_batch_size': 16,
#   'val_batch_size': 16,
#   'test_batch_size': 144,
#   'patch_size': 128,
#   'num_workers': 4,
#   'pin_memory': True},
#  'exp_params': {'LR': 0.001,
#   'weight_decay': 0.0,
#   'scheduler_gamma': 0.95,
#   'kld_weight': 3.0,
#   'accelerator': 'gpu',
#   'epochs': 100,
#   'manual_seed': 1265},
#  'logging_params': {'save_dir': 'logs/', 'name': 'VAE_128x128'}}

# %% [markdown]
# ## Track metadata and hyperparameters with `wandb.init`
#
# Define the experiment: the hyperparameters, the dataset and model name. This information will be stored in a `config` dictionary.

# %%
config_wandb = dict(
    epochs        = config["exp_params"]["epochs"],
    batch_size    = config["data_params"]["train_batch_size"],
    learning_rate = config["exp_params"]["LR"],
    kld_weight    = config["exp_params"]["kld_weight"],
    optimizer     = "Adam",
    dataset       = "CelebA",
    image_size    = [
                    config["model_params"]["in_channels"],
                    config["data_params"]["patch_size"],
                    config["data_params"]["patch_size"]
                    ],
    latent_dim    = config["model_params"]["latent_dim"],
    architecture  = "VAE-cnn"
)

# %%
config_wandb
# Out:
# {'epochs': 100,
#  'batch_size': 16,
#  'learning_rate': 0.001,
#  'optimizer': 'Adam',
#  'dataset': 'CelebA',
#  'image_size': [3, 128, 128],
#  'latent_dim': 128,
#  'architecture': 'VAE-cnn'}

# %%
wandb.init(project='VAE_CelebA', entity='ajesteves', config=config_wandb)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112460388883645, max=1.0…
# wandb version 0.16.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/esteves/pCloudDrive/sabatica2023/codigo/VAE/wandb/run-20240328_005425-mu98c130</code>
# Syncing run <strong><a href='https://wandb.ai/ajesteves/VAE_CelebA/runs/mu98c130' target="_blank">swift-pyramid-10</a></strong> to <a href='https://wandb.ai/ajesteves/VAE_CelebA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ajesteves/VAE_CelebA' target="_blank">https://wandb.ai/ajesteves/VAE_CelebA</a>
#  View run at <a href='https://wandb.ai/ajesteves/VAE_CelebA/runs/mu98c130' target="_blank">https://wandb.ai/ajesteves/VAE_CelebA/runs/mu98c130</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/ajesteves/VAE_CelebA/runs/mu98c130?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## Prepare the data and explore it

# %%
print(torch.__version__)

# setup device agnostic code

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)

# Setup path to celebA dataset folder

data_path = Path(config["data_params"]["data_path"])

train_dir = data_path / "train"
val_dir   = data_path / "val"
test_dir  = data_path / "test"
# Out:
# 2.1.1+cu121
# cuda

# %%
# Get all training image paths
train_image_list = list(train_dir.glob("*.jpg")) 

print(f'Training set size: {len(train_image_list)}')

# Get all validation image paths
val_image_list = list(val_dir.glob("*.jpg")) 

print(f'Validation set size: {len(val_image_list)}')

# Get all test image paths
test_image_list = list(test_dir.glob("*.jpg"))

print(f'Test set size: {len(test_image_list)}')
# Out:
# Training set size: 162770
# Validation set size: 19867
# Test set size: 19962

# %%
# Visualizing random images

import random
from   PIL import Image

# set seed

random.seed(42)

# Pick a random image path

rand_image_path = random.choice(train_image_list)
print(f'Randomly selected image:\n\t{rand_image_path}')

# Open the image using pillow library

img = Image.open(rand_image_path)

# Show the image and print image metadata

print(f'Random image path:   {rand_image_path}')
print(f'Random image height: {img.height}')
print(f'Random image width:  {img.width}')

display(img)
# Out:
# Randomly selected image:
# 	/home/datasets/celeba/train/029185.jpg
# Random image path:   /home/datasets/celeba/train/029185.jpg
# Random image height: 218
# Random image width:  178
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>

# %%
# Visualize an image using matplotlib

import numpy as np
import matplotlib.pyplot as plt

# convert the image 'img' to a numpy array

img_array = np.asarray(img)

# plot the image with matplotlib

plt.figure(figsize=(10,7))
plt.imshow(img_array)
plt.title(f'Image shape: {img_array.shape} (height,width,channels)')
plt.axis(False)
# Out:
# (-0.5, 177.5, 217.5, -0.5)

# %% [markdown]
# ## Transforming the Data
#
# Before we can use our data with PyTorch:
# 1. Convert the images to tensors using `torchvision.transforms`
# ([documentation](https://pytorch.org/vision/0.16//transforms.html))
# 2. Create a `torch.utils.data.Dataset` with our tensors
# 3. Convert the `Dataset` into a `torch.utils.data.DataLoader`
#
# ### (i) Convert images to tensors

# %%
from torch.utils.data import DataLoader
from torchvision      import transforms, datasets

train_transforms = transforms.Compose(
    [
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(148),
    transforms.Resize(config["data_params"]["patch_size"]),
    transforms.ToTensor()
    ]
)

val_transforms = transforms.Compose(
    [
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop(148),
    transforms.Resize(config["data_params"]["patch_size"]),
    transforms.ToTensor()
    ]
)

# %%
img_tensor = train_transforms(img)
print(img_tensor.shape)
print(img_tensor)
# Out:
# torch.Size([3, 128, 128])
# tensor([[[0.1529, 0.1255, 0.1373,  ..., 0.0941, 0.0980, 0.1020],
#          [0.1373, 0.1137, 0.1294,  ..., 0.0980, 0.1020, 0.1098],
#          [0.1255, 0.1216, 0.1373,  ..., 0.1020, 0.1059, 0.1137],
#          ...,
#          [0.1098, 0.1137, 0.1098,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1137, 0.1137, 0.1098,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1059, 0.1059, 0.1020,  ..., 0.0824, 0.0824, 0.0824]],
#
#         [[0.1765, 0.1490, 0.1608,  ..., 0.1176, 0.1216, 0.1255],
#          [0.1569, 0.1373, 0.1529,  ..., 0.1216, 0.1255, 0.1333],
#          [0.1451, 0.1451, 0.1608,  ..., 0.1255, 0.1294, 0.1373],
#          ...,
#          [0.1333, 0.1333, 0.1255,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1373, 0.1333, 0.1255,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1294, 0.1255, 0.1176,  ..., 0.0824, 0.0824, 0.0824]],
#
#         [[0.1529, 0.1333, 0.1451,  ..., 0.1176, 0.1216, 0.1255],
#          [0.1333, 0.1216, 0.1373,  ..., 0.1216, 0.1255, 0.1333],
#          [0.1255, 0.1294, 0.1451,  ..., 0.1255, 0.1294, 0.1373],
#          ...,
#          [0.1373, 0.1451, 0.1333,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1412, 0.1451, 0.1333,  ..., 0.0824, 0.0824, 0.0824],
#          [0.1333, 0.1373, 0.1255,  ..., 0.0824, 0.0824, 0.0824]]])

# %%
# Visualize transformed images

def plot_transformed_images(
    image_paths,
    transform,
    n           = 3,
    seed        = None ):
  """
  The functions selects 'n' random images from 'image_paths', load and transform them,
  then it plots the original images vs the transformed representation.
  """
  # set the random seed if it is not None
  if seed:
    random.seed(seed)

  # randomly select 'n' image paths
  rand_image_paths = random.sample(image_paths,k=n)

  # iterate throuth the 'n' selected paths
  for image_path in rand_image_paths:

    with Image.open(image_path) as f:

      # original image
      fig,ax = plt.subplots(nrows=1,ncols=2)
      ax[0].imshow(f)
      ax[0].set_title(f'Original\nSize: {f.size}')
      ax[0].axis(False)

      # transform the original image and plot the transformed representation
      transformed_image = transform(f).permute(1, 2, 0) # we need to convert C,H,W (pytorch) to H,W,C (plt)
      ax[1].imshow(transformed_image)
      ax[1].set_title(f'Transformed\nShape: {transformed_image.shape}')
      ax[1].axis(False)

      fig.suptitle(f'Class: {image_path.parent.stem}',fontsize=16)

# %%
plot_transformed_images(
    image_paths = train_image_list,
    transform   = train_transforms,
    n           = 3
)

# %% [markdown]
# ### (ii) Create a custom Dataset from the images in a folder using `torch.utils.data.Dataset`

# %%
from natsort          import natsorted
from torch.utils.data import Dataset

class CustomDataSet(Dataset):

    def __init__(self, root_dir, transform):
        self.root_dir     = root_dir
        self.transform    = transform
        self.all_images   = os.listdir(root_dir)
        self.total_images = natsorted(self.all_images)

    def __len__(self):
        return len(self.total_images)

    def __getitem__(self, idx):
        img_loc = os.path.join(self.root_dir, self.total_images[idx])
        image   = Image.open(img_loc).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image

# %%
# Create training and validation datasets

train_data = CustomDataSet(
    train_dir,
    transform = train_transforms
)

val_data = CustomDataSet(
    val_dir,
    transform = val_transforms
)

test_data = CustomDataSet(
    test_dir,
    transform = val_transforms
)

print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 162770
# 19867
# 19962

# %%
# Visualize some samples from the created training set

# Indexing the 'train_data' Dataset to get a single (image, label) sample

img  = train_data[0]

print(f'Image tensor:\n{img}')
print(f'Image shape: {img.shape}')
print(f'Image data type: {img.dtype}')
# Out:
# Image tensor:
# tensor([[[0.6118, 0.6510, 0.4902,  ..., 0.9804, 0.9765, 0.9882],
#          [0.6627, 0.6196, 0.4980,  ..., 0.9804, 0.9765, 0.9882],
#          [0.7059, 0.5843, 0.5490,  ..., 0.9804, 0.9843, 0.9922],
#          ...,
#          [0.5765, 0.5333, 0.2471,  ..., 0.5255, 0.5137, 0.5765],
#          [0.6235, 0.4863, 0.2431,  ..., 0.5725, 0.5451, 0.5333],
#          [0.6039, 0.4392, 0.2510,  ..., 0.4824, 0.4980, 0.4510]],
#
#         [[0.4627, 0.4784, 0.2980,  ..., 0.9294, 0.9216, 0.9333],
#          [0.5294, 0.4627, 0.3137,  ..., 0.9294, 0.9255, 0.9333],
#          [0.5725, 0.4353, 0.3686,  ..., 0.9294, 0.9333, 0.9373],
#          ...,
#          [0.3804, 0.3647, 0.1098,  ..., 0.2863, 0.2824, 0.3569],
#          [0.4275, 0.3176, 0.1059,  ..., 0.3412, 0.3216, 0.3020],
#          [0.4196, 0.2745, 0.1059,  ..., 0.2549, 0.2745, 0.2157]],
#
#         [[0.3137, 0.3451, 0.1882,  ..., 0.7961, 0.7882, 0.7961],
#          [0.3490, 0.3020, 0.1804,  ..., 0.7961, 0.7922, 0.8000],
#          [0.3804, 0.2471, 0.2235,  ..., 0.8000, 0.8039, 0.8039],
#          ...,
#          [0.2941, 0.2980, 0.0745,  ..., 0.1765, 0.1765, 0.2392],
#          [0.3373, 0.2588, 0.0824,  ..., 0.2235, 0.2078, 0.1882],
#          [0.3176, 0.2000, 0.0588,  ..., 0.1294, 0.1569, 0.1020]]])
# Image shape: torch.Size([3, 128, 128])
# Image data type: torch.float32

# %%
# rearrange the order of dimensions on image tensor for using matplot lib
img_permuted = img.permute(1, 2, 0) # C,H,W --> H,W,C

# print shapes
print(f'Original image shape (pytorch tensor):   {img.shape}')
print(f'Permute image shape (matplotlib format): {img_permuted.shape}')

# plot the image

plt.figure(figsize=(10,7))
plt.imshow(img_permuted)
plt.axis(False)
plt.title(f'An image from training set')
# Out:
# Original image shape (pytorch tensor):   torch.Size([3, 128, 128])
# Permute image shape (matplotlib format): torch.Size([128, 128, 3])
# Text(0.5, 1.0, 'An image from training set')

# %% [markdown]
# ### (iii) Convert the `Dataset` into a `torch.utils.data.DataLoader`
#
# A DataLoader helps us to iterate trough the dataset em get a batch of samples each time.
#
# Relevant configuration parameters:
#
# ```python
# config["data_params"]["train_batch_size"]
# config["data_params"]["val_batch_size"]
# config["data_params"]["test_batch_size"]
# config["data_params"]["num_workers"]
# config["data_params"]["pin_memory"]
# ```

# %%
# Convert each 'Dataset' into a 'DataLoader'

from torch.utils.data import DataLoader

train_dataloader = DataLoader(
    dataset     = train_data,
    batch_size  = config["data_params"]["train_batch_size"],
    shuffle     = True,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

val_dataloader = DataLoader(
    dataset     = val_data,
    batch_size  = config["data_params"]["val_batch_size"],
    shuffle     = False,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

test_dataloader = DataLoader(
    dataset     = test_data,
    batch_size  = config["data_params"]["test_batch_size"],
    shuffle     = False,
    num_workers = config["data_params"]["num_workers"],
    pin_memory  = config["data_params"]["pin_memory"]
)

# %%
print(train_dataloader)
print(val_dataloader)
print(test_dataloader)

print(len(train_dataloader)) # returns the number of batches in a training epoch
print(len(val_dataloader))   # returns the number of batches in a validation epoch
print(len(test_dataloader))  # returns the number of batches in a test epoch
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fa18d5b0550>
# <torch.utils.data.dataloader.DataLoader object at 0x7fa18d5def10>
# <torch.utils.data.dataloader.DataLoader object at 0x7fa1b026ac90>
# 10174
# 1242
# 139

# %%
# print metadata about a sample retrieved from the training DataLoader

imgs = next(iter(train_dataloader))

print(f'Batch of images shape: {imgs.shape}')   # BS, Ch, H, W
# Out:
# Batch of images shape: torch.Size([16, 3, 128, 128])

# %% [markdown]
# ## The VAE Model

# %%
class VanillaVAE(nn.Module):

    def __init__(
        self,
        in_channels: int,
        latent_dim:  int,
        hidden_dims: List = None,
        **kwargs
        ) -> None:

        super(VanillaVAE, self).__init__()

        self.latent_dim = latent_dim

        modules = []
        if hidden_dims is None:
            hidden_dims = [16, 32, 64, 128, 128]

        # Build the Encoder ...........................................

        # Define 5 blocks composed of: Conv2D -> BatchNorm2d -> LeakyReLU
        for h_dim in hidden_dims:
            modules.append(
                nn.Sequential(
                    nn.Conv2d(
                        in_channels,
                        out_channels = h_dim,
                        kernel_size  = 3,
                        stride       = 2, 
                        padding      = 1
                        ),
                    nn.BatchNorm2d(h_dim),
                    nn.LeakyReLU())
            )
            in_channels = h_dim

        # Add the 5 blocks to the encoder model
        self.encoder = nn.Sequential(*modules)

        # Fully connected layer that outputs the latent mean 
        self.fc_mu   = nn.Linear(
            in_features  = hidden_dims[-1]*16, 
            out_features = latent_dim
        )
        # Fully connected layer that outputs the latent log-variance 
        self.fc_var  = nn.Linear(
            in_features  = hidden_dims[-1]*16,
            out_features = latent_dim
        )

        # Build the Decoder ...........................................

        modules = []

        # Fully connected layer to make the latent variables to have the
        # correct shape for decoder
        self.decoder_input = nn.Linear(
            in_features  = latent_dim,
            out_features = hidden_dims[-1] * 16
        )

        # hidden_dims = [128, 128, 64, 32, 16]
        hidden_dims.reverse()

        # Define 4 blocks composed of: ConvTranspose2d -> BatchNorm2d -> LeakyReLU
        for i in range(len(hidden_dims) - 1):
            modules.append(
                nn.Sequential(
                    nn.ConvTranspose2d(
                        hidden_dims[i],
                        hidden_dims[i+1],
                        kernel_size    = 3,
                        stride         = 2,
                        padding        = 1,
                        output_padding = 1
                    ),
                    nn.BatchNorm2d(hidden_dims[i+1]),
                    nn.LeakyReLU())
            )

        # Add the 4 blocks to the decoder model
        self.decoder = nn.Sequential(*modules)

        # Add a final block to the decoder composed of:
        #   ConvTranspose2d -> BatchNorm2d -> LeakyReLU -> Conv2d -> Tanh
        self.final_layer = nn.Sequential(
            nn.ConvTranspose2d(
                hidden_dims[-1],
                hidden_dims[-1],
                kernel_size=3,
                stride=2,
                padding=1,
                output_padding=1
            ),
            nn.BatchNorm2d(hidden_dims[-1]),
            nn.LeakyReLU(),
            nn.Conv2d(
                hidden_dims[-1],
                out_channels = 3,
                kernel_size  = 3,
                padding      = 1
            ),
            nn.Sigmoid()
        )

    def encode(self, input: Tensor) -> List[Tensor]:
        """
        Encodes the input by passing through the encoder network
        and returns the latent mean and log-variance.

        Arguments:
            * input: Input tensor to encoder [N x C x H x W]
        Returns:
            A list containing the mean and the log-variance of latent distribution.
        """

        # Passes 'input' through the encoder
        result  = self.encoder(input)

        # Flatten the encoder output
        result  = torch.flatten(result, start_dim=1)

        # Split the result into the mean and variance
        # of the latent Normal distribution
        mu      = self.fc_mu(result)
        log_var = self.fc_var(result)

        return [mu, log_var]

    def decode(self, z: Tensor) -> Tensor:
        """
        Maps the given latent variable 'z' back to the image space.

        Arguments:
            * z: (Tensor) [B x D]
        Returns:
            * The image generated by the decoder,
              a tensor with shape [B x C x H x W].
        """
        # Reshape latent 'z' with the fully connected layer
        result = self.decoder_input(z)
        # Reorganize the latent dimensions
        result = result.view(-1, 128, 4, 4)
        # Pass data through the 4 decoder blocks
        result = self.decoder(result)
        # Pass data through the final block
        result = self.final_layer(result)
        return result

    def reparameterize(self, mu: Tensor, logvar: Tensor) -> Tensor:
        """
        Reparameterization trick to allow the gradient flow through
        the latent sampler. In this way, sampling 'z' from N(mu, var) is
        modified to sampling 'eps' from N(0,1) followed by the definition
        z = mu + eps * e^logvar.

        Arguments:
            * mu: Mean of the latent Normal distribution, a tensor [B x D]
            * logvar: Log-variance of the latent Normal distribution, a tensor [B x D]
        Returns:
            The latent variable 'z', a tensor [B x D].
        """
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps * std + mu

    def forward(self, input: Tensor, **kwargs) -> List[Tensor]:
        '''
        Defines the forward pass through the VAE: 
        encoder -> reparameterization -> decoder
        '''
        mu, log_var = self.encode(input)
        z           = self.reparameterize(mu, log_var)
        x           = self.decode(z)
        return  [x, input, mu, log_var]

    def loss_function(
        self,
        reconst_img: Tensor,
        input_img:   Tensor,
        mu:          Tensor,
        log_var:     Tensor,
        kld_weight:  float ) -> dict:
        '''
        Computes the VAE loss = reconstruction_loss + KLD_loss * kld_weight

        Arguments:
            * args
            * kwargs
        Returns:
            A tuple containing (loss, reconstruction term of loss, KLD term of loss)
        '''
        reconst_img  = reconst_img
        input_img    = input_img
        mu           = mu
        log_var      = log_var
        kld_weight   = kld_weight # Account for the minibatch samples from the dataset

        # Reconstruction term of the loss: SUM (x-x_reconstructed)^2
        reconst_loss = F.mse_loss(reconst_img, input_img, reduction='sum')

        # KL Divergence term of the loss
        #  D_KL(Normal(mu, var) || Normal(0, 1)) = -0.5 * [ log (var) + 1 - var^2 - mu^2 ]
        kld_loss = -0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp())

        # Loss = -ELBO
        batch_size    = mu.shape[0]
        reconst_loss /= batch_size
        kld_loss     /= batch_size
        loss = reconst_loss + kld_weight * kld_loss

        # print(f'Loss shape: {loss.shape} -> {loss}')

        return loss, reconst_loss, kld_loss

    def sample(
        self,
        num_samples:    int,
        current_device: int,
        **kwargs
        ) -> Tensor:
        """
        Samples the latent space and returns the corresponding reconstructed image.

        Arguments:
            * num_samples: Number of samples (an Int)
            * current_device: Device to run the model (an Int)
        Returns:
            The recontructed images given the samples (a tensor).
        """

        # Draw 'num_samples' samples from the standard Normal N(0,1)
        z = torch.randn(num_samples, self.latent_dim)

        # Put the sample in the same device of the model
        z = z.to(current_device)

        # Reconstruct 'num_samples' images from the samples that we draw
        samples = self.decode(z)

        return samples

    def generate(self, x: Tensor, **kwargs) -> Tensor:
        """
        Given input images 'x', passes them through the VAE and returns 
        the reconstructed images.

        Arguments:
            * x: Input images (a tensor [B x C x H x W]).
        Returns:
            The reconstructed images (a tensor [B x C x H x W]).
        """

        return self.forward(x)[0]

# %%
model = VanillaVAE(**config['model_params']).to(device)

model
# Out:
# VanillaVAE(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (fc_mu): Linear(in_features=2048, out_features=192, bias=True)
#   (fc_var): Linear(in_features=2048, out_features=192, bias=True)
#   (decoder_input): Linear(in_features=192, out_features=2048, bias=True)
#   (decoder): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (final_layer): Sequential(
#     (0): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(16, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Sigmoid()
#   )
# )

# %%
from torchinfo import summary

summary(model, input_size=(64, 3, 128, 128))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VanillaVAE                               [64, 3, 128, 128]         --
# ├─Sequential: 1-1                        [64, 128, 4, 4]           --
# │    └─Sequential: 2-1                   [64, 16, 64, 64]          --
# │    │    └─Conv2d: 3-1                  [64, 16, 64, 64]          448
# │    │    └─BatchNorm2d: 3-2             [64, 16, 64, 64]          32
# │    │    └─LeakyReLU: 3-3               [64, 16, 64, 64]          --
# │    └─Sequential: 2-2                   [64, 32, 32, 32]          --
# │    │    └─Conv2d: 3-4                  [64, 32, 32, 32]          4,640
# │    │    └─BatchNorm2d: 3-5             [64, 32, 32, 32]          64
# │    │    └─LeakyReLU: 3-6               [64, 32, 32, 32]          --
# │    └─Sequential: 2-3                   [64, 64, 16, 16]          --
# │    │    └─Conv2d: 3-7                  [64, 64, 16, 16]          18,496
# │    │    └─BatchNorm2d: 3-8             [64, 64, 16, 16]          128
# │    │    └─LeakyReLU: 3-9               [64, 64, 16, 16]          --
# │    └─Sequential: 2-4                   [64, 128, 8, 8]           --
# │    │    └─Conv2d: 3-10                 [64, 128, 8, 8]           73,856
# │    │    └─BatchNorm2d: 3-11            [64, 128, 8, 8]           256
# │    │    └─LeakyReLU: 3-12              [64, 128, 8, 8]           --
# │    └─Sequential: 2-5                   [64, 128, 4, 4]           --
# │    │    └─Conv2d: 3-13                 [64, 128, 4, 4]           147,584
# │    │    └─BatchNorm2d: 3-14            [64, 128, 4, 4]           256
# │    │    └─LeakyReLU: 3-15              [64, 128, 4, 4]           --
# ├─Linear: 1-2                            [64, 192]                 393,408
# ├─Linear: 1-3                            [64, 192]                 393,408
# ├─Linear: 1-4                            [64, 2048]                395,264
# ├─Sequential: 1-5                        [64, 16, 64, 64]          --
# │    └─Sequential: 2-6                   [64, 128, 8, 8]           --
# │    │    └─ConvTranspose2d: 3-16        [64, 128, 8, 8]           147,584
# │    │    └─BatchNorm2d: 3-17            [64, 128, 8, 8]           256
# │    │    └─LeakyReLU: 3-18              [64, 128, 8, 8]           --
# │    └─Sequential: 2-7                   [64, 64, 16, 16]          --
# │    │    └─ConvTranspose2d: 3-19        [64, 64, 16, 16]          73,792
# │    │    └─BatchNorm2d: 3-20            [64, 64, 16, 16]          128
# │    │    └─LeakyReLU: 3-21              [64, 64, 16, 16]          --
# │    └─Sequential: 2-8                   [64, 32, 32, 32]          --
# │    │    └─ConvTranspose2d: 3-22        [64, 32, 32, 32]          18,464
# │    │    └─BatchNorm2d: 3-23            [64, 32, 32, 32]          64
# │    │    └─LeakyReLU: 3-24              [64, 32, 32, 32]          --
# │    └─Sequential: 2-9                   [64, 16, 64, 64]          --
# │    │    └─ConvTranspose2d: 3-25        [64, 16, 64, 64]          4,624
# │    │    └─BatchNorm2d: 3-26            [64, 16, 64, 64]          32
# │    │    └─LeakyReLU: 3-27              [64, 16, 64, 64]          --
# ├─Sequential: 1-6                        [64, 3, 128, 128]         --
# │    └─ConvTranspose2d: 2-10             [64, 16, 128, 128]        2,320
# │    └─BatchNorm2d: 2-11                 [64, 16, 128, 128]        32
# │    └─LeakyReLU: 2-12                   [64, 16, 128, 128]        --
# │    └─Conv2d: 2-13                      [64, 3, 128, 128]         435
# │    └─Sigmoid: 2-14                     [64, 3, 128, 128]         --
# ==========================================================================================
# Total params: 1,675,571
# Trainable params: 1,675,571
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 8.38
# ==========================================================================================
# Input size (MB): 12.58
# Forward/backward pass size (MB): 548.60
# Params size (MB): 6.70
# Estimated Total Size (MB): 567.89
# ==========================================================================================

# %% [markdown]
# To test our model let us do a single forward pass (pass a sample batch from the training set through the model).

# %%
# 1. Get a batch of images from the training DataLoader

img_batch = next(iter(train_dataloader))

# 2. Get a single image from the batch and unsqueeze the image
#    so its shape fits the model

img_single = img_batch[0].unsqueeze(dim=0)
print(f"Single image shape: {img_single.shape}\n")

# 3. Perform a forward pass on a single image

model.eval()
with torch.inference_mode():
    img_out, img_in, mu_out, logvar_out = model(img_single.to(device))

# 4. Print output

print(f"Img output:\n{img_out}\n")
print(f"Mean:\n{mu_out}\n")
print(f"LogVar:\n{logvar_out}\n")
# Out:
# Single image shape: torch.Size([1, 3, 128, 128])
#
# Img output:
# tensor([[[[0.4852, 0.4834, 0.4847,  ..., 0.4834, 0.4843, 0.4844],
#           [0.4862, 0.4842, 0.4847,  ..., 0.4843, 0.4853, 0.4851],
#           [0.4880, 0.4865, 0.4882,  ..., 0.4865, 0.4878, 0.4864],
#           ...,
#           [0.4863, 0.4842, 0.4848,  ..., 0.4842, 0.4854, 0.4850],
#           [0.4878, 0.4860, 0.4875,  ..., 0.4860, 0.4873, 0.4860],
#           [0.4843, 0.4817, 0.4824,  ..., 0.4818, 0.4827, 0.4834]],
#
#          [[0.5099, 0.5103, 0.5104,  ..., 0.5103, 0.5106, 0.5107],
#           [0.5109, 0.5108, 0.5108,  ..., 0.5109, 0.5110, 0.5125],
#           [0.5106, 0.5124, 0.5129,  ..., 0.5125, 0.5133, 0.5135],
#           ...,
#           [0.5107, 0.5108, 0.5108,  ..., 0.5108, 0.5109, 0.5124],
#           [0.5108, 0.5123, 0.5129,  ..., 0.5124, 0.5132, 0.5131],
#           [0.5117, 0.5118, 0.5115,  ..., 0.5119, 0.5116, 0.5122]],
#
#          [[0.5033, 0.5051, 0.5049,  ..., 0.5052, 0.5046, 0.5078],
#           [0.5041, 0.5072, 0.5067,  ..., 0.5073, 0.5063, 0.5078],
#           [0.5039, 0.5072, 0.5064,  ..., 0.5073, 0.5061, 0.5081],
#           ...,
#           [0.5040, 0.5071, 0.5068,  ..., 0.5073, 0.5062, 0.5079],
#           [0.5043, 0.5073, 0.5065,  ..., 0.5074, 0.5064, 0.5080],
#           [0.5060, 0.5090, 0.5084,  ..., 0.5089, 0.5085, 0.5076]]]],
#        device='cuda:0')
#
# Mean:
# tensor([[ 3.1287e-02,  9.2912e-03, -1.0958e-03, -6.9993e-03,  2.9427e-02,
#          -3.2318e-02, -2.4095e-03,  1.0712e-02, -1.0455e-02, -6.9180e-03,
#          -1.0069e-02, -6.6739e-03, -3.1023e-02, -5.6910e-03,  1.2507e-02,
#          -8.9478e-03,  2.2408e-02,  6.8058e-03,  1.2551e-02, -2.8756e-02,
#          -1.6966e-02,  1.6195e-02,  1.0181e-02,  2.1816e-03,  1.3398e-03,
#          -3.9441e-02, -6.1653e-03,  1.6289e-02,  3.9934e-03,  8.4933e-03,
#           5.7108e-03, -1.9196e-03,  2.5181e-02, -3.0361e-03,  3.8816e-03,
#          -7.0185e-03, -6.9237e-03, -2.2866e-02,  1.6923e-02, -2.0542e-02,
#          -5.9539e-03, -2.5982e-02,  2.9605e-03, -1.9611e-03, -7.4526e-03,
#           9.2124e-03,  2.3938e-02,  2.4490e-02,  6.4164e-03,  2.2705e-02,
#           4.5349e-03,  4.5783e-03, -8.4584e-03,  2.8784e-02,  2.3458e-02,
#           2.6468e-02,  2.2280e-02,  6.1534e-03, -1.9385e-02, -1.8185e-04,
#           2.2285e-03, -1.4795e-02, -1.5975e-02,  2.0057e-02,  2.9566e-02,
#          -1.8855e-02,  1.1877e-02,  2.4064e-02, -2.6470e-02,  8.7116e-03,
#           9.7441e-03, -1.0264e-02,  1.0960e-02, -4.6767e-03,  8.0161e-03,
#          -6.0501e-03, -2.1685e-02,  7.9437e-03, -5.0024e-03,  3.6801e-02,
#          -1.0206e-02, -2.2195e-02, -8.6685e-03,  2.5522e-02, -1.8898e-02,
#           6.7451e-03,  2.4799e-02,  4.8219e-03,  1.9393e-03, -1.0043e-02,
#           2.1867e-02,  4.9384e-03, -4.2308e-03, -7.7526e-04, -7.5529e-03,
#          -1.9251e-03,  1.3311e-03,  4.3077e-03,  9.6141e-03,  9.6093e-04,
#           1.5428e-02, -3.5086e-03,  1.3010e-02, -1.7925e-02,  2.3870e-03,
#           1.0748e-02,  4.6283e-02, -1.4640e-02, -9.4389e-03, -2.5051e-02,
#          -1.7739e-03, -9.5235e-03,  3.4143e-03,  6.9453e-03, -1.7035e-03,
#          -2.7191e-03, -5.4862e-03,  2.4319e-02,  1.9044e-02, -1.9112e-02,
#           1.1096e-02, -2.4294e-03,  1.6046e-03,  4.2487e-05,  1.3467e-02,
#          -2.2548e-02,  1.6304e-02,  1.5884e-02, -3.4908e-02, -9.0615e-03,
#          -1.0797e-02, -2.1099e-02, -9.3475e-03, -1.0236e-02,  5.0184e-02,
#           1.5666e-02, -1.4868e-02, -3.1047e-02,  1.3822e-02,  1.5262e-02,
#           5.1916e-03, -3.5371e-02,  1.4694e-03,  1.4449e-02,  2.0647e-02,
#          -2.6115e-02,  5.2886e-03, -4.6202e-03, -2.6204e-03, -9.8308e-03,
#           1.5844e-02,  1.5008e-02,  1.7916e-03, -6.9803e-03, -6.9238e-03,
#          -3.5985e-03, -5.4310e-03,  2.1348e-02,  7.3762e-03, -7.0589e-03,
#           3.7506e-03, -4.5364e-03,  2.7067e-03, -8.0728e-04,  8.1644e-03,
#          -3.3528e-03,  6.1066e-03, -1.2730e-02,  2.0285e-03, -1.2639e-02,
#          -3.1001e-03, -2.4032e-02,  1.5080e-02,  1.6403e-02,  4.9110e-03,
#          -3.5934e-02, -1.0028e-02, -1.8589e-03, -9.9689e-03, -1.1167e-02,
#          -2.2295e-03,  6.5671e-03, -1.6538e-03,  1.3406e-02, -1.3687e-03,
#           1.6441e-02,  1.8593e-02,  3.9129e-02, -2.7935e-04,  2.9711e-02,
#           1.6040e-02, -1.1251e-02]], device='cuda:0')
#
# LogVar:
# tensor([[-2.0960e-02, -1.2727e-02,  4.7883e-03, -5.2083e-03, -3.1531e-03,
#           3.4208e-03, -7.7385e-03, -2.1404e-03,  6.9418e-04,  1.4311e-02,
#          -2.5751e-03, -3.2124e-02,  1.3006e-03,  4.1420e-02,  1.3711e-02,
#           5.0135e-03, -1.1615e-02,  1.9880e-03, -8.9770e-04, -1.6638e-02,
#          -1.1089e-02, -4.9513e-03,  2.0051e-02, -7.5969e-03,  4.3818e-03,
#          -2.6613e-02,  1.1301e-02,  3.4156e-02,  1.2942e-02, -9.3261e-03,
#          -7.2408e-04, -1.3310e-03,  1.6930e-02, -1.4400e-02, -3.9833e-02,
#          -2.6714e-03, -1.7382e-02,  3.9083e-03, -2.8328e-02, -1.5288e-02,
#           1.4421e-03, -2.2249e-02,  1.9184e-02, -1.5495e-03,  1.6060e-03,
#          -3.3054e-03, -2.0407e-02,  1.0852e-02, -5.0947e-03,  1.6607e-02,
#          -1.2606e-02,  1.4110e-05,  1.1925e-02,  4.2760e-03, -1.0465e-02,
#          -7.5328e-03, -4.0166e-02, -2.7275e-02,  7.8604e-03,  1.3054e-02,
#          -1.8937e-03,  1.2341e-02,  4.3050e-03,  1.3598e-02,  1.4830e-02,
#          -4.3810e-03, -2.0719e-02, -7.6538e-03, -2.2346e-02, -2.0206e-02,
#           8.7194e-03,  2.3397e-02, -6.3060e-03,  3.0610e-03,  1.2514e-02,
#           2.6297e-02, -3.2903e-03,  1.4498e-02,  1.0986e-02,  5.7336e-03,
#           4.4184e-03,  2.2361e-02, -7.3278e-03,  8.7835e-03,  2.7167e-02,
#           1.3470e-02, -4.1493e-04,  2.0202e-02, -2.1125e-02, -4.1260e-04,
#          -3.9415e-03,  2.6542e-03, -3.8734e-02,  2.7493e-02, -1.3595e-02,
#           1.4674e-02,  2.8469e-02, -1.5642e-02, -1.8628e-02, -1.1165e-02,
#          -1.0708e-03, -2.7073e-02, -5.7297e-03,  9.7979e-03, -6.1889e-03,
#          -9.1966e-03,  5.5029e-03,  2.7723e-02, -5.7909e-04, -3.0481e-03,
#          -1.2696e-02, -3.0777e-02, -7.7270e-03,  3.2274e-03,  8.8594e-03,
#           2.1050e-02, -3.6596e-03, -1.2173e-02, -8.9221e-03, -2.0137e-02,
#           1.1839e-02, -6.9397e-03, -1.0868e-02,  8.3826e-03,  7.0054e-03,
#          -1.8751e-02, -7.7606e-03,  2.1880e-02,  6.8104e-03,  2.1030e-02,
#          -6.5457e-03, -1.9791e-02,  6.6771e-03,  1.8637e-02, -1.0878e-02,
#           9.2007e-03,  2.4706e-02,  1.0049e-02,  1.2257e-02,  1.4258e-02,
#          -2.5940e-02, -1.0246e-02,  1.9715e-02, -2.1647e-02, -5.0259e-03,
#          -2.1821e-02, -3.1193e-03, -1.3921e-02, -5.4406e-03,  8.3371e-04,
#           3.1368e-03, -1.9113e-02, -1.8017e-02,  2.7769e-02,  2.2194e-03,
#           1.3983e-02, -3.6221e-02,  1.1486e-02,  7.3639e-03, -3.4309e-02,
#          -1.0054e-02, -1.3462e-02,  7.9059e-03, -8.8971e-03,  1.0515e-02,
#           1.6618e-02, -2.8342e-02,  1.9294e-02,  1.5485e-03,  2.4738e-03,
#           2.8592e-02,  1.6328e-02,  1.7562e-02, -4.0445e-03, -2.1627e-02,
#           1.5891e-02,  2.1968e-02, -9.6024e-03,  2.6836e-02,  4.5778e-04,
#          -5.1423e-03,  6.1265e-03,  1.6968e-02,  2.6635e-02,  5.7568e-03,
#          -3.3240e-02, -8.1066e-03,  3.4497e-03, -2.3068e-02, -1.3821e-02,
#           1.6045e-02, -1.7669e-02]], device='cuda:0')

# %% [markdown]
# ## Creating `train_step()` and `val_step()` functions and `train()` to combine them
#
# Let us start by making `train_step()`.

# %%
def train_step(
    model:      torch.nn.Module,
    dataloader: torch.utils.data.DataLoader,
    loss_fn:    torch.nn.Module,
    optimizer:  torch.optim.Optimizer,
    kld_weight: float,
    epoch_id:   int,
    device:     torch.device,
    ) -> Tuple[float, float, float]:
    """
    Trains a PyTorch model for a single epoch.

    Turns a target PyTorch model to training mode and then
    runs through all of the required training steps (forward
    pass, loss calculation, optimizer step).

    Arguments:
        model:      A PyTorch model to be trained.
        dataloader: A DataLoader instance for the model to be trained on.
        loss_fn:    A PyTorch loss function to minimize.
        optimizer:  A PyTorch optimizer to help minimize the loss function.
        kld_weight: Weight to apply to the KLD term of the loss.
        device:     A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A tuple of training loss, reconstruction loss, kld loss.
        In the form (train_loss, reconst_loss, kld_loss). For example:

        (0.3456, 0.8743, 0.5678)
    """

    # Put model in train mode
    model.train()

    # Setup train loss, reconstruction loss, and KLD loss values
    train_loss         = 0.
    train_reconst_loss = 0.
    train_kld_loss     = 0.

    # Loop through data loader data batches
    for batch, X in enumerate(dataloader):
        # Send data to target device
        X = X.to(device)

        # 1. Forward pass
        X_out, _, mu_out, logvar_out = model(X)

        # 2. Calculate and accumulate losses
        loss, reconst_loss, kld_loss = loss_fn(
            X_out,
            X,
            mu_out,
            logvar_out,
            kld_weight,
        )

        train_loss         += loss.item()
        train_reconst_loss += reconst_loss.item()
        train_kld_loss     += kld_loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

    # Adjust losses to get average value per batch
    train_loss         = train_loss / len(dataloader)
    train_reconst_loss = train_reconst_loss / len(dataloader)
    train_kld_loss     = train_kld_loss / len(dataloader)

    return train_loss, train_reconst_loss, train_kld_loss

# %% [markdown]
# Now we will implement `val_step()`.

# %%
def val_step(
    model:      torch.nn.Module,
    dataloader: torch.utils.data.DataLoader,
    loss_fn:    torch.nn.Module,
    kld_weight: float,
    epoch_id:   int,
    device:     torch.device) -> Tuple[float, float, float]:
    """
    Runs a validation step with a PyTorch model for a single epoch.

    Turns a target PyTorch model to "eval" mode and then performs
    a forward pass on a testing dataset.

    Arguments:
        model:      A PyTorch model to be tested.
        dataloader: A DataLoader instance for the model to be tested on.
        loss_fn:    A PyTorch loss function to calculate loss on the test data.
        kld_weight: Weight to apply to the KLD term of the loss.
        device:     A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A tuple of validation loss, reconstruction loss, kld loss.
        In the form (train_loss, reconst_loss, kld_loss). For example:

        (0.3456, 0.8743, 0.5678)
    """
    # Put model in eval mode
    model.eval()

    # Setup validation loss, reconstruction loss, and KLD loss values
    val_loss         = 0.
    val_reconst_loss = 0.
    val_kld_loss     = 0.

    # Turn on inference context manager
    with torch.inference_mode():

        # Loop through DataLoader batches
        for batch, X in enumerate(dataloader):

            # Send data to target device
            X = X.to(device)

            # 1. Forward pass
            X_out, _, mu_out, logvar_out = model(X)

            # 2. Calculate and accumulate losses
            loss, reconst_loss, kld_loss = loss_fn(
                X_out,
                X,
                mu_out,
                logvar_out,
                kld_weight,
            )

            val_loss         += loss.item()
            val_reconst_loss += reconst_loss.item()
            val_kld_loss     += kld_loss.item()

    # Adjust losses to get average value per batch
    val_loss         = val_loss / len(dataloader)
    val_reconst_loss = val_reconst_loss / len(dataloader)
    val_kld_loss     = val_kld_loss / len(dataloader)

    return val_loss, val_reconst_loss, val_kld_loss

# %% [markdown]
# And we will combine `train_step()` and `val_step()` into `train()`.

# %%
from tqdm.auto import tqdm

def train(
    model: torch.nn.Module,
    train_dataloader: torch.utils.data.DataLoader,
    val_dataloader:   torch.utils.data.DataLoader,
    optimizer:        torch.optim.Optimizer,
    loss_fn:          torch.nn.Module,
    kld_weight:       float,
    epochs:           int,
    device:           torch.device ) -> Dict[str, List[float]]:
    """
    Trains and validates a PyTorch model.

    Passes a target PyTorch models through train_step() and val_step()
    functions for a number of epochs, training and validating the model
    in the same epoch loop.

    Calculates, prints and stores evaluation metrics throughout.

    Arguments:
        model:            A PyTorch model to be trained and tested.
        train_dataloader: A DataLoader instance for the model to be trained on.
        val_dataloader:   A DataLoader instance for the model to be tested on.
        optimizer:        A PyTorch optimizer to help minimize the loss function.
        loss_fn:          A PyTorch loss function to calculate loss on both datasets.
        kld_weight:       Weight to apply to the KLD term of the loss.
        epochs:           An integer indicating how many epochs to train for.
        device:           A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
        A dictionary of training and validation losses. Each metric has a value 
        in a list for each epoch.
        In the form:
            {
            train_loss:         [...],
            train_reconst_loss: [...],
            train_kld_loss:     [...],
            val_loss:           [...],
            val_reconst_loss:   [...],
            val_kld_loss:       [...]
            }
        For example if training for epochs=2:
            {
            train_loss:         [2.0616, 1.0537],
            train_reconst_loss: [0.3945, 0.4945],
            train_kld_loss:     [0.5945, 0.6945],
            val_loss:           [1.2641, 1.5706],
            val_reconst_loss:   [0.7400, 0.8973],
            val_kld_loss:       [0.9945, 0.0545],
            }
    """

    # Create empty results dictionary
    results = {
        "train_loss":         [],
        "train_reconst_loss": [],
        "train_kld_loss":     [],
        "val_loss":           [],
        "val_reconst_loss":   [],
        "val_kld_loss":       []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):

        train_loss, train_rec_loss, train_kld_loss = train_step(
            model      = model,
            dataloader = train_dataloader,
            loss_fn    = loss_fn,
            optimizer  = optimizer,
            kld_weight = kld_weight,
            epoch_id   = epoch,
            device     = device,
        )

        val_loss, val_rec_loss, val_kld_loss = val_step(
            model      = model,
            dataloader = test_dataloader,
            loss_fn    = loss_fn,
            kld_weight = kld_weight,
            epoch_id   = epoch,
            device     = device
        )

        # Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"Losses-> train: {train_loss:.4f} | "
            f"train_rec: {train_rec_loss:.4f} | "
            f"train_kld: {train_kld_loss:.4f} | "
            f"val: {val_loss:.4f} | "
            f"val_rec: {val_rec_loss:.4f} | "
            f"val_kld: {val_kld_loss:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_reconst_loss"].append(train_rec_loss)
        results["train_kld_loss"].append(train_kld_loss)
        results["val_loss"].append(val_loss)
        results["val_reconst_loss"].append(val_rec_loss)
        results["val_kld_loss"].append(val_kld_loss)

        # Log metrics to W&B
        wandb.log(
            {
            "train_loss":     train_loss,
            "train_rec_loss": train_rec_loss,
            "train_kld_loss": train_kld_loss,
            "val_loss":       val_loss,
            "val_rec_loss":   val_rec_loss,
            "val_kld_loss":   val_kld_loss,
            "epoch":          epoch,
            }
        )

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ## Create a function to save the model
#
# Let us setup a function to save our model to a directory.

# %%
from pathlib import Path

def save_model(
    model: torch.nn.Module,
    target_dir: str,
    model_name: str ):
    """
    Saves a PyTorch model to a target directory.

    Args:
        model:      A target PyTorch model to save.
        target_dir: A directory for saving the model to.
        model_name: A filename for the saved model. Should include
                    either ".pth" or ".pt" as the file extension.

    Example of usage:
        save_model(
            model=model_0,
            target_dir="models",
            model_name="05_going_modular_tingvgg_model.pth"
        )
    """
    # Create target directory
    target_dir_path = Path(target_dir)
    target_dir_path.mkdir(parents=True, exist_ok=True)

    # Create model save path
    assert model_name.endswith(".pth") or model_name.endswith(".pt"), "model_name should end with '.pt' or '.pth'"
    model_save_path = target_dir_path / model_name

    # Save the model state_dict()
    print(f"[INFO] Saving model to: {model_save_path}")
    torch.save(
        obj = model.state_dict(),
        f   = model_save_path
    )

# %% [markdown]
# ## Train, validate and save the model
#
# Let us leverage the functions we have got above to train, validate and save a model to file.

# %%
# Set random seeds

torch.manual_seed(config["exp_params"]["manual_seed"])
torch.cuda.manual_seed(config["exp_params"]["manual_seed"])

# Recreate an instance of VanillaVAE

model_vae = VanillaVAE(**config['model_params']).to(device)

# Setup loss function and optimizer

loss_fn = model_vae.loss_function

optimizer = torch.optim.Adam(
    params = model_vae.parameters(), 
    lr     = config["exp_params"]["LR"]
)

# Tell wandb to watch what the model gets up to: gradients, weights, and more
#
#wandb.watch(model_vae, loss_fn, log="all", log_freq=10)

# Start the timer

from timeit import default_timer as timer
start_time = timer()

# Train model_vae

vae_results = train(model=model_vae,
    train_dataloader = train_dataloader,
    val_dataloader   = val_dataloader,
    optimizer        = optimizer,
    loss_fn          = loss_fn,
    kld_weight       = config["exp_params"]["kld_weight"],
    epochs           = config["exp_params"]["epochs"],
    device           = device
)

# End the timer and print out how long it took

end_time = timer()
print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")

# Save the model to file

save_model(model=model_vae,
    target_dir = "models",
    model_name = f"{BASE_FILE_NAME}.pth"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | Losses-> train: 905.4844 | train_rec: 706.3733 | train_kld: 66.3704 | val: 749.0469 | val_rec: 548.4966 | val_kld: 66.8501
# Epoch: 2 | Losses-> train: 759.7319 | train_rec: 552.9992 | train_kld: 68.9109 | val: 720.8165 | val_rec: 513.2245 | val_kld: 69.1973
# Epoch: 3 | Losses-> train: 734.1990 | train_rec: 524.3010 | train_kld: 69.9660 | val: 704.2440 | val_rec: 494.5363 | val_kld: 69.9026
# Epoch: 4 | Losses-> train: 720.2412 | train_rec: 508.8471 | train_kld: 70.4647 | val: 699.3477 | val_rec: 491.3478 | val_kld: 69.3333
# Epoch: 5 | Losses-> train: 712.2364 | train_rec: 499.6525 | train_kld: 70.8613 | val: 690.1226 | val_rec: 480.8063 | val_kld: 69.7721
# Epoch: 6 | Losses-> train: 704.9249 | train_rec: 491.5511 | train_kld: 71.1246 | val: 687.3783 | val_rec: 483.5439 | val_kld: 67.9448
# Epoch: 7 | Losses-> train: 700.0642 | train_rec: 486.0617 | train_kld: 71.3342 | val: 684.1589 | val_rec: 473.2505 | val_kld: 70.3028
# Epoch: 8 | Losses-> train: 696.3710 | train_rec: 481.8619 | train_kld: 71.5030 | val: 677.2571 | val_rec: 469.1737 | val_kld: 69.3611
# Epoch: 9 | Losses-> train: 693.0233 | train_rec: 478.1251 | train_kld: 71.6327 | val: 675.5304 | val_rec: 461.5312 | val_kld: 71.3331
# Epoch: 10 | Losses-> train: 690.0001 | train_rec: 474.7371 | train_kld: 71.7543 | val: 671.7814 | val_rec: 463.2390 | val_kld: 69.5141
# Epoch: 11 | Losses-> train: 687.5301 | train_rec: 472.1238 | train_kld: 71.8021 | val: 692.0017 | val_rec: 476.5604 | val_kld: 71.8138
# Epoch: 12 | Losses-> train: 685.8834 | train_rec: 470.4032 | train_kld: 71.8267 | val: 671.2876 | val_rec: 455.6155 | val_kld: 71.8907
# Epoch: 13 | Losses-> train: 684.0926 | train_rec: 468.4811 | train_kld: 71.8705 | val: 672.0019 | val_rec: 459.9496 | val_kld: 70.6841
# Epoch: 14 | Losses-> train: 682.1851 | train_rec: 466.5186 | train_kld: 71.8888 | val: 666.4524 | val_rec: 453.4825 | val_kld: 70.9900
# Epoch: 15 | Losses-> train: 680.6849 | train_rec: 464.8306 | train_kld: 71.9514 | val: 663.1997 | val_rec: 449.9075 | val_kld: 71.0974
# Epoch: 16 | Losses-> train: 679.6135 | train_rec: 463.5461 | train_kld: 72.0225 | val: 667.2635 | val_rec: 447.2386 | val_kld: 73.3417
# Epoch: 17 | Losses-> train: 678.3601 | train_rec: 462.1598 | train_kld: 72.0668 | val: 671.5782 | val_rec: 458.2345 | val_kld: 71.1146
# Epoch: 18 | Losses-> train: 677.2030 | train_rec: 461.0230 | train_kld: 72.0600 | val: 670.4884 | val_rec: 459.6416 | val_kld: 70.2823
# Epoch: 19 | Losses-> train: 676.2269 | train_rec: 459.8013 | train_kld: 72.1418 | val: 660.0910 | val_rec: 444.2781 | val_kld: 71.9376
# Epoch: 20 | Losses-> train: 674.9708 | train_rec: 458.3815 | train_kld: 72.1964 | val: 661.1758 | val_rec: 451.0840 | val_kld: 70.0306
# Epoch: 21 | Losses-> train: 673.7100 | train_rec: 456.8075 | train_kld: 72.3008 | val: 658.6187 | val_rec: 445.2835 | val_kld: 71.1117
# Epoch: 22 | Losses-> train: 672.7271 | train_rec: 455.5634 | train_kld: 72.3879 | val: 657.9310 | val_rec: 446.9767 | val_kld: 70.3181
# Epoch: 23 | Losses-> train: 671.4944 | train_rec: 454.1253 | train_kld: 72.4564 | val: 657.7292 | val_rec: 441.3897 | val_kld: 72.1132
# Epoch: 24 | Losses-> train: 670.6798 | train_rec: 453.2708 | train_kld: 72.4697 | val: 660.1104 | val_rec: 448.5206 | val_kld: 70.5299
# Epoch: 25 | Losses-> train: 669.9771 | train_rec: 452.3891 | train_kld: 72.5293 | val: 659.8342 | val_rec: 444.3583 | val_kld: 71.8253
# Epoch: 26 | Losses-> train: 669.2929 | train_rec: 451.5037 | train_kld: 72.5964 | val: 659.8947 | val_rec: 446.4207 | val_kld: 71.1580
# Epoch: 27 | Losses-> train: 668.6210 | train_rec: 450.6858 | train_kld: 72.6451 | val: 654.4884 | val_rec: 434.2473 | val_kld: 73.4137
# Epoch: 28 | Losses-> train: 667.6837 | train_rec: 449.5119 | train_kld: 72.7239 | val: 655.5222 | val_rec: 443.9332 | val_kld: 70.5297
# Epoch: 29 | Losses-> train: 667.0388 | train_rec: 448.9475 | train_kld: 72.6971 | val: 658.6874 | val_rec: 442.9170 | val_kld: 71.9234
# Epoch: 30 | Losses-> train: 666.1662 | train_rec: 447.9388 | train_kld: 72.7425 | val: 656.6162 | val_rec: 441.8674 | val_kld: 71.5829
# Epoch: 31 | Losses-> train: 665.6322 | train_rec: 447.2798 | train_kld: 72.7841 | val: 652.4669 | val_rec: 434.3819 | val_kld: 72.6950
# Epoch: 32 | Losses-> train: 665.1929 | train_rec: 446.7187 | train_kld: 72.8247 | val: 652.6086 | val_rec: 433.8287 | val_kld: 72.9266
# Epoch: 33 | Losses-> train: 664.5438 | train_rec: 445.9636 | train_kld: 72.8601 | val: 655.8189 | val_rec: 439.1289 | val_kld: 72.2300
# Epoch: 34 | Losses-> train: 664.1907 | train_rec: 445.5042 | train_kld: 72.8955 | val: 652.2410 | val_rec: 437.0751 | val_kld: 71.7220
# Epoch: 35 | Losses-> train: 663.7475 | train_rec: 445.0164 | train_kld: 72.9104 | val: 651.5447 | val_rec: 435.4717 | val_kld: 72.0243
# Epoch: 36 | Losses-> train: 663.2471 | train_rec: 444.3607 | train_kld: 72.9621 | val: 651.3481 | val_rec: 439.3331 | val_kld: 70.6717
# Epoch: 37 | Losses-> train: 662.7426 | train_rec: 443.9398 | train_kld: 72.9343 | val: 650.9838 | val_rec: 433.5686 | val_kld: 72.4717
# Epoch: 38 | Losses-> train: 662.3991 | train_rec: 443.4952 | train_kld: 72.9680 | val: 651.7619 | val_rec: 434.9343 | val_kld: 72.2759
# Epoch: 39 | Losses-> train: 662.0804 | train_rec: 443.1040 | train_kld: 72.9921 | val: 649.3620 | val_rec: 429.4950 | val_kld: 73.2890
# Epoch: 40 | Losses-> train: 661.7097 | train_rec: 442.5928 | train_kld: 73.0390 | val: 662.1320 | val_rec: 453.1587 | val_kld: 69.6578
# Epoch: 41 | Losses-> train: 661.0909 | train_rec: 442.1040 | train_kld: 72.9956 | val: 652.5885 | val_rec: 438.1107 | val_kld: 71.4926
# Epoch: 42 | Losses-> train: 660.7075 | train_rec: 441.7150 | train_kld: 72.9975 | val: 649.9571 | val_rec: 432.5679 | val_kld: 72.4631
# Epoch: 43 | Losses-> train: 660.6527 | train_rec: 441.5372 | train_kld: 73.0385 | val: 652.4852 | val_rec: 435.4786 | val_kld: 72.3355
# Epoch: 44 | Losses-> train: 660.0711 | train_rec: 440.9998 | train_kld: 73.0238 | val: 648.0910 | val_rec: 425.7625 | val_kld: 74.1095
# Epoch: 45 | Losses-> train: 659.6728 | train_rec: 440.5420 | train_kld: 73.0436 | val: 649.7083 | val_rec: 435.2656 | val_kld: 71.4809
# Epoch: 46 | Losses-> train: 659.2855 | train_rec: 440.2732 | train_kld: 73.0041 | val: 647.8238 | val_rec: 434.8254 | val_kld: 70.9995
# Epoch: 47 | Losses-> train: 659.1651 | train_rec: 440.0601 | train_kld: 73.0350 | val: 649.4993 | val_rec: 434.5284 | val_kld: 71.6570
# Epoch: 48 | Losses-> train: 658.8899 | train_rec: 439.7587 | train_kld: 73.0437 | val: 649.5211 | val_rec: 433.5223 | val_kld: 71.9996
# Epoch: 49 | Losses-> train: 658.4031 | train_rec: 439.3512 | train_kld: 73.0173 | val: 646.7048 | val_rec: 425.7734 | val_kld: 73.6438
# Epoch: 50 | Losses-> train: 658.2666 | train_rec: 438.9996 | train_kld: 73.0890 | val: 652.0737 | val_rec: 435.0235 | val_kld: 72.3500
# Epoch: 51 | Losses-> train: 657.8525 | train_rec: 438.6111 | train_kld: 73.0805 | val: 644.9730 | val_rec: 427.8663 | val_kld: 72.3689
# Epoch: 52 | Losses-> train: 657.6835 | train_rec: 438.5150 | train_kld: 73.0562 | val: 648.3688 | val_rec: 423.6589 | val_kld: 74.9033
# Epoch: 53 | Losses-> train: 657.4280 | train_rec: 438.1813 | train_kld: 73.0822 | val: 644.3082 | val_rec: 429.1451 | val_kld: 71.7210
# Epoch: 54 | Losses-> train: 657.1603 | train_rec: 438.0789 | train_kld: 73.0271 | val: 649.9166 | val_rec: 429.4656 | val_kld: 73.4837
# Epoch: 55 | Losses-> train: 656.8045 | train_rec: 437.6043 | train_kld: 73.0667 | val: 645.1930 | val_rec: 430.2277 | val_kld: 71.6551
# Epoch: 56 | Losses-> train: 656.6625 | train_rec: 437.5005 | train_kld: 73.0540 | val: 645.6552 | val_rec: 431.1611 | val_kld: 71.4981
# Epoch: 57 | Losses-> train: 656.3598 | train_rec: 437.1408 | train_kld: 73.0730 | val: 648.0146 | val_rec: 434.4150 | val_kld: 71.1999
# Epoch: 58 | Losses-> train: 656.0242 | train_rec: 436.7966 | train_kld: 73.0758 | val: 646.0122 | val_rec: 426.1333 | val_kld: 73.2930
# Epoch: 59 | Losses-> train: 655.9226 | train_rec: 436.7199 | train_kld: 73.0676 | val: 645.5757 | val_rec: 429.8956 | val_kld: 71.8934
# Epoch: 60 | Losses-> train: 655.7339 | train_rec: 436.4952 | train_kld: 73.0796 | val: 647.6716 | val_rec: 431.5027 | val_kld: 72.0563
# Epoch: 61 | Losses-> train: 655.7182 | train_rec: 436.4153 | train_kld: 73.1010 | val: 646.5561 | val_rec: 424.3113 | val_kld: 74.0816
# Epoch: 62 | Losses-> train: 655.2957 | train_rec: 436.0683 | train_kld: 73.0758 | val: 645.3397 | val_rec: 430.6582 | val_kld: 71.5605
# Epoch: 63 | Losses-> train: 655.3096 | train_rec: 436.0601 | train_kld: 73.0832 | val: 645.2826 | val_rec: 428.2956 | val_kld: 72.3290
# Epoch: 64 | Losses-> train: 655.1122 | train_rec: 435.8246 | train_kld: 73.0959 | val: 644.0818 | val_rec: 431.8922 | val_kld: 70.7299
# Epoch: 65 | Losses-> train: 654.8322 | train_rec: 435.6086 | train_kld: 73.0745 | val: 645.0489 | val_rec: 434.8213 | val_kld: 70.0759
# Epoch: 66 | Losses-> train: 654.4772 | train_rec: 435.1957 | train_kld: 73.0939 | val: 644.9573 | val_rec: 429.6977 | val_kld: 71.7532
# Epoch: 67 | Losses-> train: 654.4298 | train_rec: 435.1875 | train_kld: 73.0808 | val: 645.5206 | val_rec: 429.5540 | val_kld: 71.9889
# Epoch: 68 | Losses-> train: 654.1357 | train_rec: 434.9274 | train_kld: 73.0694 | val: 649.8729 | val_rec: 433.0867 | val_kld: 72.2621
# Epoch: 69 | Losses-> train: 654.2342 | train_rec: 434.9328 | train_kld: 73.1005 | val: 644.8266 | val_rec: 431.3788 | val_kld: 71.1493
# Epoch: 70 | Losses-> train: 653.7728 | train_rec: 434.6622 | train_kld: 73.0369 | val: 643.3154 | val_rec: 429.9585 | val_kld: 71.1190
# Epoch: 71 | Losses-> train: 653.7521 | train_rec: 434.5178 | train_kld: 73.0781 | val: 644.0272 | val_rec: 426.5069 | val_kld: 72.5068
# Epoch: 72 | Losses-> train: 653.4806 | train_rec: 434.2768 | train_kld: 73.0679 | val: 645.7749 | val_rec: 432.9987 | val_kld: 70.9254
# Epoch: 73 | Losses-> train: 653.2635 | train_rec: 434.0593 | train_kld: 73.0681 | val: 644.0015 | val_rec: 428.8871 | val_kld: 71.7048
# Epoch: 74 | Losses-> train: 653.2274 | train_rec: 433.9511 | train_kld: 73.0921 | val: 643.3582 | val_rec: 426.4559 | val_kld: 72.3008
# Epoch: 75 | Losses-> train: 653.0345 | train_rec: 433.7546 | train_kld: 73.0933 | val: 643.9081 | val_rec: 428.3014 | val_kld: 71.8689
# Epoch: 76 | Losses-> train: 652.9135 | train_rec: 433.6739 | train_kld: 73.0799 | val: 654.8616 | val_rec: 439.2900 | val_kld: 71.8572
# Epoch: 77 | Losses-> train: 652.6853 | train_rec: 433.3943 | train_kld: 73.0970 | val: 644.1460 | val_rec: 431.6669 | val_kld: 70.8264
# Epoch: 78 | Losses-> train: 652.7330 | train_rec: 433.4097 | train_kld: 73.1078 | val: 645.3503 | val_rec: 430.2111 | val_kld: 71.7131
# Epoch: 79 | Losses-> train: 652.4917 | train_rec: 433.2621 | train_kld: 73.0765 | val: 643.3423 | val_rec: 422.6260 | val_kld: 73.5721
# Epoch: 80 | Losses-> train: 652.2421 | train_rec: 432.9975 | train_kld: 73.0815 | val: 643.9894 | val_rec: 426.7886 | val_kld: 72.4003
# Epoch: 81 | Losses-> train: 652.1269 | train_rec: 432.8229 | train_kld: 73.1013 | val: 642.0808 | val_rec: 417.6573 | val_kld: 74.8078
# Epoch: 82 | Losses-> train: 652.0082 | train_rec: 432.7501 | train_kld: 73.0860 | val: 642.4327 | val_rec: 423.0283 | val_kld: 73.1348
# Epoch: 83 | Losses-> train: 651.8866 | train_rec: 432.5703 | train_kld: 73.1054 | val: 641.3783 | val_rec: 424.7894 | val_kld: 72.1963
# Epoch: 84 | Losses-> train: 651.8152 | train_rec: 432.5111 | train_kld: 73.1014 | val: 642.4216 | val_rec: 426.3094 | val_kld: 72.0374
# Epoch: 85 | Losses-> train: 651.6487 | train_rec: 432.4296 | train_kld: 73.0730 | val: 640.8337 | val_rec: 420.4773 | val_kld: 73.4521
# Epoch: 86 | Losses-> train: 651.4589 | train_rec: 432.2361 | train_kld: 73.0743 | val: 642.7772 | val_rec: 423.9831 | val_kld: 72.9314
# Epoch: 87 | Losses-> train: 651.3160 | train_rec: 432.0939 | train_kld: 73.0740 | val: 644.2006 | val_rec: 429.8005 | val_kld: 71.4667
# Epoch: 88 | Losses-> train: 651.1883 | train_rec: 431.9787 | train_kld: 73.0699 | val: 647.0643 | val_rec: 430.2593 | val_kld: 72.2683
# Epoch: 89 | Losses-> train: 650.9953 | train_rec: 431.8232 | train_kld: 73.0574 | val: 640.8363 | val_rec: 424.3881 | val_kld: 72.1494
# Epoch: 90 | Losses-> train: 651.0935 | train_rec: 431.7644 | train_kld: 73.1097 | val: 642.4888 | val_rec: 425.0072 | val_kld: 72.4939
# Epoch: 91 | Losses-> train: 650.9592 | train_rec: 431.7144 | train_kld: 73.0816 | val: 641.1881 | val_rec: 424.4856 | val_kld: 72.2342
# Epoch: 92 | Losses-> train: 650.7381 | train_rec: 431.4846 | train_kld: 73.0845 | val: 640.3699 | val_rec: 425.9795 | val_kld: 71.4635
# Epoch: 93 | Losses-> train: 650.4272 | train_rec: 431.2350 | train_kld: 73.0641 | val: 640.9796 | val_rec: 421.3262 | val_kld: 73.2178
# Epoch: 94 | Losses-> train: 650.4287 | train_rec: 431.2535 | train_kld: 73.0584 | val: 643.7915 | val_rec: 430.6505 | val_kld: 71.0470
# Epoch: 95 | Losses-> train: 650.4713 | train_rec: 431.2161 | train_kld: 73.0851 | val: 639.7720 | val_rec: 424.2229 | val_kld: 71.8497
# Epoch: 96 | Losses-> train: 650.3021 | train_rec: 431.1321 | train_kld: 73.0567 | val: 650.6996 | val_rec: 441.7202 | val_kld: 69.6598
# Epoch: 97 | Losses-> train: 649.9590 | train_rec: 430.7876 | train_kld: 73.0571 | val: 643.8175 | val_rec: 426.1647 | val_kld: 72.5509
# Epoch: 98 | Losses-> train: 650.2450 | train_rec: 431.0099 | train_kld: 73.0784 | val: 646.2518 | val_rec: 428.7686 | val_kld: 72.4944
# Epoch: 99 | Losses-> train: 650.0249 | train_rec: 430.8630 | train_kld: 73.0540 | val: 650.7714 | val_rec: 426.2283 | val_kld: 74.8477
# Epoch: 100 | Losses-> train: 649.9033 | train_rec: 430.7460 | train_kld: 73.0525 | val: 639.2876 | val_rec: 422.3540 | val_kld: 72.3112
# [INFO] Total training time: 16732.569 seconds
# [INFO] Saving model to: models/VAE_CelebA_128x128_04.pth

# %% [markdown]
# ## Save results to a CSV file
#
# Convert the `vae_results` dictionary, containing list with the loss values, to a DataFrame and later to a CSV file.

# %%
vae_results_df = pd.concat({k: pd.Series(v) for k, v in vae_results.items()}, axis=1)

vae_results_df.to_csv(
    f"results/{BASE_FILE_NAME}_results.csv",
    sep=',',
    index=False,
    encoding='utf-8'
)

# %% [markdown]
# ## Plot the training and validation losses

# %%
vae_results_df[["train_loss", "train_reconst_loss", "train_kld_loss"]].plot()
vae_results_df[["val_loss", "val_reconst_loss", "val_kld_loss"]].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Reconstruct images drawn from the test set and generate new images given samples from the latent distribution

# %%
from torchvision.utils import save_image

def reconstruct_sample_images(
    model:             torch.nn.Module,
    test_dataloader:   torch.utils.data.DataLoader,
    file_inputs:       Union[str, Path],
    file_reconstructs: Union[str, Path],
    file_samples:      Union[str, Path],
    device:            torch.device
    ):
    '''
    Get a batch of images from test DataLoader, pass them through the model 
    and save the reconstructed images to file.
    Get 144 samples from latent distribution, generate the correspondent images
    and save the images to file.

    Arguments:
        model:             The PyTorch model. 
        test_dataloader:   The test DataLoader to get the images that 
                           will be used in reconstruction.
        file_inputs:       File/Path to save the batch of input images used in reconstruction.
        file_reconstructs: File/Path to save the batch of reconstructed images.
        file_samples:      File/Path to save the 144 generated images.
        device:            A target device where the model is located (e.g. "cuda" or "cpu").
    '''
    # Get a batch of images from the test Dataloader that will be used in reconstruction
    input_img = next(iter(test_dataloader))

    # Save the batch of images retrieved from the test Dataloader to a file
    save_image(
        input_img.data,
        file_inputs,
        normalize = True,
        nrow      = 12
    )

    # Pass the batch of images through the model
    input_img = input_img.to(device)
    recons_img = model.generate(input_img)

    # Save the reconstructed images to a file
    save_image(
        recons_img.cpu().data,
        file_reconstructs,
        normalize = True,
        nrow      = 12
    )

    try:
        # Get 144 samples from the latent distribution 
        # and pass them through the decoder <=> generate images
        generated_img = model.sample(144, device)

        # Save the generated images to a file
        save_image(
            generated_img.cpu().data, 
            file_samples,
            normalize=True,
            nrow=12
        )
    except Warning:
        pass

# %%
reconstruct_sample_images(
    model_vae,
    test_dataloader,
    file_inputs       = f"results/{BASE_FILE_NAME}_input.jpg",
    file_reconstructs = f"results/{BASE_FILE_NAME}_reconstructed.jpg",
    file_samples      = f"results/{BASE_FILE_NAME}_generated.jpg",
    device            = device,
)

# %%
def reconstruct_sample_images_v2(
    model:             torch.nn.Module,
    test_dataloader:   torch.utils.data.DataLoader,
    file_inputs:       Union[str, Path],
    file_reconstructs: Union[str, Path],
    file_samples:      Union[str, Path],
    nrows:             int,
    ncols:             int,
    device:            torch.device
    ):
    '''
    Get a batch of images from test DataLoader and pass them through the model.
    Among the batch of input images, save a grid of nrowsxncols images to a file.
    Among the batch of reconstructed images, save a grid of nrowsxncols images to a file.
    Get 144 samples from latent distribution, generate the correspondent images
    and save a grid of nrowsxncols generated images to file.

    Arguments:
        model:             The PyTorch model. 
        test_dataloader:   The test DataLoader to get the images that 
                           will be used in reconstruction.
        file_inputs:       File/Path to save the batch of input images used in reconstruction.
        file_reconstructs: File/Path to save the batch of reconstructed images.
        file_samples:      File/Path to save the 144 generated images.
        nrows:             Number of rowns of images to save to the files.
        nvols:             Number of columnss of images to save to the files.
        device:            A target device where the model is located (e.g. "cuda" or "cpu").
    '''
    # Get a batch of images from the test Dataloader that will be used in reconstruction
    input_img = next(iter(test_dataloader))

    assert nrows*ncols <= len(input_img), f"{nrows*ncols} must be less or equal to thebatch size ({len(input_img)})"

    # Save the batch of images retrieved from the test Dataloader to a file
    save_image(
        input_img[0:nrows*ncols].data,
        file_inputs,
        normalize = True,
        nrow      = ncols,
    )

    # Pass the batch of images through the model
    input_img  = input_img.to(device)
    recons_img = model.generate(input_img)

    # Save the reconstructed images to a file
    save_image(
        recons_img[0:nrows*ncols].cpu().data,
        file_reconstructs,
        normalize = True,
        nrow      = ncols,
    )

    try:
        # Get 144 samples from the latent distribution 
        # and pass them through the decoder <=> generate images
        generated_img = model.sample(144, device)

        # Save the generated images to a file
        save_image(
            generated_img[0:nrows*ncols].cpu().data, 
            file_samples,
            normalize=True,
            nrow=ncols,
        )
    except Warning:
        pass

# %%
reconstruct_sample_images_v2(
    model_vae,
    test_dataloader,
    file_inputs       = f"results/{BASE_FILE_NAME}_input_8x4.jpg",
    file_reconstructs = f"results/{BASE_FILE_NAME}_reconstructed_8x4.jpg",
    file_samples      = f"results/{BASE_FILE_NAME}_generated_8x4.jpg",
    nrows             = 8,
    ncols             = 4,
    device            = device,
)

# %% [markdown]
# ## Results
#
# Input images:
# ![](results/vae_antixz_64x64_input.jpg)

# %% [markdown]
# Reconstructed images:
# ![](results/vae_antixz_64x64_reconstructed.jpg)

# %% [markdown]
# Generated new images:
# ![](results/vae_antixz_64x64_generated.jpg)
